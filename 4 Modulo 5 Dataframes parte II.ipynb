# %% [markdown]
# ![](Logo3.png)

# %% [markdown]
# # Modulo V  Dataframes
#
#
# ## Tabla de Contenido
#
# [5.7 Borrar columnas o renglones en dataframes  ](#id7)<br>
# [5.8 Agregar columnas en dataframes  ](#id8)<br>
# ...  [5.8.1  Reemplazar valores ](#id81)<br>
# [5.9 Group by dataframe](#id9)<br>
# ... [5.9.1 Ejercicio de Group By](#id91)<br>
# ... [5.9.2 Aggregación](#id92)<br>
# [5.10 Merge Dataframes](#id10)<br>
# [5.11 Exportar Dataframe a CSV, Excel](#id11)<br>
# [5.12 PIVOT Tables](#id12)<br>
# [5.13 Leer archivo de Excel](#id13)<br>
# [5.14 Convertir tipos de datos](#id14)<br>
# [5.15 Formatting the Display Dataframe](#id15)

# %% [markdown]
# ![](Pandas_python.png)
#
# ## Pandas
#
# - Es una **biblioteca de código abierto** para Python que agrega **estructuras de datos de alto rendimiento** y **herramientas para el análisis de grandes conjuntos de datos**.
# - Las **estructuras de datos de pandas** incluyen las **series** y las estructuras **dataframes (marco de datos)**.
# - **Los dataframes son la principal estructura de pandas**.
# - Pandas es una **librería externa** y se tiene que instalar. (En el caso de Anaconda viene instalado).
# - Se importa en un programa de Python mediante la instruccion import.
# - Es convencional utilizar **import pandas as pd** para facilitar la escritura de las referencias a los componentes de pandas.

# %% [markdown]
# ##  5.1 Introducción a Dataframes en Pandas   <a id='id1'> </a>
#
# ![](dataframe.png)
#
# ### Dataframe
#
# - Un DataFrame es conceptualmente un **objeto de serie bidimensional, donde hay un índice y varias columnas de contenido**, con cada columna que tiene una etiqueta.
# - Un Dataframe es una matriz de dos ejes etiquetada. Es como una tabla de datos de Excel.
# - Se utiliza para **almacenar cualquier tipo de información**.
# - El Dataframe (marcos de datos) son la principal estructura de pandas, además de la más utilizada para el análisis de datos.
# - Loss marcos de datos se construyen fácilmente de una variedad de otras estructuras de datos y archivos externos, como archivos de Excel o achivos CSV.
# - Hay una **amplia variedad de métodos disponibles** para objetos de marcos de datos.
# - Las filas y columnas se pueden manipular de diversas maneras y los operadores están disponibles para realizar transformaciones matemáticas, de cadena y lógicas al contenido del marco de datos.
#
#
# ![](The_dataframe.png)

# %% [markdown]
# ###  Documentación de Referencia
#
# - Lista de métodos de dataframe
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
# Primero debemos importar la libreria de pandas
# Es convencional utilizar import pandas as pd

import pandas as pd
import numpy as np

# %% [markdown]
# ## 5.7 Borrar columnas o renglones en dataframes  <a id='id7'> </a>
#
# - Se usa la funcion **drop** para borrar renglones o columnas
# - La función drop no cambia el DataFrame de forma predeterminada, en su lugar, devuelve una copia del DataFrame con las filas eliminadas.
#
# **Drop** tiene dos parámetros opcionales
# - El primero se llama **in place** y si se establece en **True**, el DataFrame se actualizará en su lugar, en lugar de devolver una copia.
# - El segundo parámetro es **axis**, que especifica que se debe borrar. De forma predeterminada, este valor es **0 para borrar las filas**. Pero puede cambiarlo a **1 si desea borrar una columna**.

# %%
covid = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
# Out:
# C:\Users\jgab\AppData\Local\Temp\ipykernel_20268\3233244115.py:1: DtypeWarning: Columns (33) have mixed types. Specify dtype option on import or set low_memory=False.
#   covid = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")

# %%
Estado1 = pd.Series( {'Estado': 'Aguascalientes',
                    'AportacionesFederales': 10676000000,
                    'ParticipacionesFederales': 7158000000,
                    'RecaudacionImpuestos': 1232000000} )
Estado2 = pd.Series( {'Estado': 'Baja California',
                    'AportacionesFederales': 20518000000,
                    'ParticipacionesFederales': 19401000000,
                    'RecaudacionImpuestos': 4341000000} )
Estado3 = pd.Series( {'Estado': 'Baja California Sur',
                    'AportacionesFederales': 7173000000,
                    'ParticipacionesFederales': 4809000000,
                    'RecaudacionImpuestos': 1112000000} )
Estado4 = pd.Series( {'Estado': 'Campeche',
                    'AportacionesFederales': 8835000000,
                    'ParticipacionesFederales':  5628000000,
                    'RecaudacionImpuestos': 1663000000} )

Ingresos = pd.DataFrame( [Estado1, Estado2, Estado3, Estado4] )
Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
IngresosCopia = Ingresos.copy()

# %%
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Borrar el renglon con indice 3

IngresosCopia.drop(3)
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# El borrado lo hace en una copia y no lo borra definitivamente

IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Para que el borrado sea definitivo, debemos agregar el atributo inplace = True

IngresosCopia.drop(3, inplace= True)

# %%
# Ahora si vemos que se borro definitivamente
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# Si queremos borrar una columna debemos especificar que es sobre el eje 1, es decir
# sobre las columnas

IngresosCopia.drop("AportacionesFederales", axis = 1)
# Out:
#                 Estado  ParticipacionesFederales  RecaudacionImpuestos
# 0       Aguascalientes                7158000000            1232000000
# 1      Baja California               19401000000            4341000000
# 2  Baja California Sur                4809000000            1112000000

# %%
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000

# %%
# NUevamente, especificar inplace = True

IngresosCopia.drop("AportacionesFederales", axis = 1, inplace = True)

# %%
IngresosCopia
# Out:
#                 Estado  ParticipacionesFederales  RecaudacionImpuestos
# 0       Aguascalientes                7158000000            1232000000
# 1      Baja California               19401000000            4341000000
# 2  Baja California Sur                4809000000            1112000000

# %%
#   Volvemos a copiar el dataframe ingresos

IngresosCopia = Ingresos.copy()
IngresosCopia
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Es mas facil borrrar si se establece como indice el estado

IngresosCopia.set_index("Estado", inplace = True)
IngresosCopia
# Out:
#                      AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes                 10676000000                7158000000
# Baja California                20518000000               19401000000
# Baja California Sur             7173000000                4809000000
# Campeche                        8835000000                5628000000
#
#                      RecaudacionImpuestos
# Estado
# Aguascalientes                 1232000000
# Baja California                4341000000
# Baja California Sur            1112000000
# Campeche                       1663000000

# %%
IngresosCopia.drop("Baja California Sur", inplace = True)
IngresosCopia
# Out:
#                  AportacionesFederales  ParticipacionesFederales  \
# Estado
# Aguascalientes             10676000000                7158000000
# Baja California            20518000000               19401000000
# Campeche                    8835000000                5628000000
#
#                  RecaudacionImpuestos
# Estado
# Aguascalientes             1232000000
# Baja California            4341000000
# Campeche                   1663000000

# %% [markdown]
# ### Alternativa 2 de borrado de columnas de dataframes
#
# - Esta opción tiene efecto inmediato

# %%
del IngresosCopia["ParticipacionesFederales"]

# %%
IngresosCopia
# Out:
#                  AportacionesFederales  RecaudacionImpuestos
# Estado
# Aguascalientes             10676000000            1232000000
# Baja California            20518000000            4341000000
# Campeche                    8835000000            1663000000

# %% [markdown]
# ## 5.8 Agregar columnas en dataframes <a id='id8'> </a>

# %%
# Verificamos los datos actuales que tenemos en el dataframe Ingresos

Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos
# 0            1232000000
# 1            4341000000
# 2            1112000000
# 3            1663000000

# %%
# Agregamos una nueva columna calculada que sume las 3 columnas existentes 

# La diagonal invertida la usamos para continuar el código en otr línea

Ingresos["Total"] = Ingresos["AportacionesFederales"] + \
                    Ingresos["ParticipacionesFederales"] + \
                    Ingresos["RecaudacionImpuestos"]

# %%
Ingresos
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
#
#    RecaudacionImpuestos        Total
# 0            1232000000  19066000000
# 1            4341000000  44260000000
# 2            1112000000  13094000000
# 3            1663000000  16126000000

# %% [markdown]
# ### 5.8.1  Reemplazar valores   <a id='id81'> </a>
#
# - En el dataset COVID necesitamos reemplazar los valores que vienen codificados como SEXO, RESULTADO, etc.

# %%
covid.head(10)
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a       2       4           2   Mujer
# 1          31/07/2020      0d6511       2       4          11  Hombre
# 2          31/07/2020      0baff6       2       9           9   Mujer
# 3          31/07/2020      1b5b75       2       9           9   Mujer
# 4          31/07/2020      120290       2       9          15   Mujer
# 5          31/07/2020      0e8480       2      12           8  Hombre
# 6          31/07/2020      0d51e8       2       9          15  Hombre
# 7          31/07/2020      07cd25       2       9          30   Mujer
# 8          31/07/2020      14a0c9       2       9          28  Hombre
# 9          31/07/2020      15843c       2       9          15  Hombre
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
# 5  No especificado            8             37   Ambulatorio  ...
# 6  No especificado           15             37   Ambulatorio  ...
# 7  No especificado           30             68   Ambulatorio  ...
# 8  No especificado           28              3   Ambulatorio  ...
# 9  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
# 5             No       No            No         No               No
# 6             No       No            No         No               No
# 7             No       No            No         No               No
# 8             No       No            No         No               No
# 9             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
# 5   Positivo         2  Estados Unidos de AmÃ©rica          99  No aplica
# 6   Positivo         2                       Suiza          99  No aplica
# 7   Positivo         2                    Colombia          99  No aplica
# 8   Positivo        99                     Malasia          99  No aplica
# 9   Positivo         2  Estados Unidos de AmÃ©rica          99  No aplica
#
# [10 rows x 35 columns]

# %%
# Contra valores de ORIGEN

covid['ORIGEN'].value_counts()
# Out:
# 2    647734
# 1    336554
# Name: ORIGEN, dtype: int64

# %%
covid["ORIGEN"].replace(2, "ISSSTE")
# Out:
# 0         ISSSTE
# 1         ISSSTE
# 2         ISSSTE
# 3         ISSSTE
# 4         ISSSTE
#            ...
# 984283         1
# 984284    ISSSTE
# 984285         1
# 984286         1
# 984287         1
# Name: ORIGEN, Length: 984288, dtype: object

# %%
# Al verificar vemos que no realizo el cambio en el dataframe original

covid['ORIGEN'].value_counts()
# Out:
# 2    647734
# 1    336554
# Name: ORIGEN, dtype: int64

# %%
# Volvemos a ejecutar pero ahora con inplace = True

covid["ORIGEN"].replace(2, "ISSSTE", inplace = True)

# %%
covid['ORIGEN'].value_counts()
# Out:
# ISSSTE    647734
# 1         336554
# Name: ORIGEN, dtype: int64

# %%
covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
#
# [5 rows x 35 columns]

# %% [markdown]
# ## 5.9 Group by dataframe  <a id='id9'> </a>
#
# - Una operación groupby implica alguna combinación de dividir el objeto en función de los valores de una columna o más, aplicar una función y combinar los resultados.
# - Esto se puede usar para agrupar grandes cantidades de datos y calcular operaciones en estos grupos.
# - **Groupby** esencialmente **divide los datos en diferentes grupos dependiendo de la(s) variable(s) de su elección**.
#
# "agrupar por" implica uno o más de los siguientes pasos:
#
# - Dividir los datos en grupos según algunos criterios.
# - Aplicar una función a cada grupo de forma independiente.
# - Combinar los resultados en una estructura de datos.
#
# ![](GroupBy.png)

# %%
#  df = pd.read_csv("20-07-31-COVID19MEXICO-codificado.csv")
covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ...  \
# 0  No especificado            2              4   Ambulatorio  ...
# 1  No especificado           11             20   Ambulatorio  ...
# 2  No especificado            9             16   Ambulatorio  ...
# 3  No especificado           15             37   Ambulatorio  ...
# 4  No especificado           15             37   Ambulatorio  ...
#
#   CARDIOVASCULAR OBESIDAD RENAL_CRONICA TABAQUISMO        OTRO_CASO  \
# 0             No       No            No         No  No especificado
# 1             No       No            No         No  No especificado
# 2             No       No            No         No               Si
# 3             Si       No            No         No               No
# 4             No       No            No         No               No
#
#    RESULTADO  MIGRANTE           PAIS_NACIONALIDAD PAIS_ORIGEN        UCI
# 0   Positivo        99                 El Salvador          99  No aplica
# 1   Positivo        99  Estados Unidos de AmÃ©rica          99  No aplica
# 2   Positivo        99                      Brasil          99  No aplica
# 3   Positivo        99                     EspaÃ±a          99  No aplica
# 4   Positivo         2                   Argentina          99  No aplica
#
# [5 rows x 35 columns]

# %%
covid['ENTIDAD_NAC'].value_counts().sort_values()
# Out:
# Colima                   3120
# No especificado          4878
# Queretaro                5528
# Quintana Roo             6448
# Baja California Sur      7072
# Nayarit                  7206
# Campeche                 7441
# Morelos                  8248
# Zacatecas                8991
# Aguascalientes          10872
# Chihuahua               11562
# Chiapas                 12611
# Tlaxcala                13004
# Hidalgo                 13560
# Baja California         14281
# Durango                 14551
# Yucatan                 20486
# Oaxaca                  23198
# Guerrero                25001
# San Luis Potosí         26609
# Sonora                  27003
# Sinaloa                 27701
# Michoacan               31085
# Coahuila                35351
# Tamaulipas              37945
# Jalisco                 39303
# Tabasco                 39673
# Nuevo León              41314
# Puebla                  43654
# Veracruz                46019
# Guanajuato              50623
# México                 112236
# Ciudad de México       207714
# Name: ENTIDAD_NAC, dtype: int64

# %%
covid['ENTIDAD_NAC'].value_counts().sort_index()
# Out:
# Aguascalientes          10872
# Baja California         14281
# Baja California Sur      7072
# Campeche                 7441
# Chiapas                 12611
# Chihuahua               11562
# Ciudad de México       207714
# Coahuila                35351
# Colima                   3120
# Durango                 14551
# Guanajuato              50623
# Guerrero                25001
# Hidalgo                 13560
# Jalisco                 39303
# Michoacan               31085
# Morelos                  8248
# México                 112236
# Nayarit                  7206
# No especificado          4878
# Nuevo León              41314
# Oaxaca                  23198
# Puebla                  43654
# Queretaro                5528
# Quintana Roo             6448
# San Luis Potosí         26609
# Sinaloa                 27701
# Sonora                  27003
# Tabasco                 39673
# Tamaulipas              37945
# Tlaxcala                13004
# Veracruz                46019
# Yucatan                 20486
# Zacatecas                8991
# Name: ENTIDAD_NAC, dtype: int64

# %% [markdown]
# ### Ejemplo 1
#
# #### Agrupar por entidad de nacimiento y contar cuantas pruebas se realizaron por entidad

# %%
# Al agrupar los datos por la columna ENTIDAD_NAC genera el calculo con cada
# una de las columnas.  Esto es ineficiente ya que son muchos registros y varias columnas


covid.groupby(['ENTIDAD_NAC']).count().head(10)
# Out:
#                      FECHA_ACTUALIZACION  ID_REGISTRO  ORIGEN  SECTOR  \
# ENTIDAD_NAC
# Aguascalientes                     10872        10872   10872   10872
# Baja California                    14281        14281   14281   14281
# Baja California Sur                 7072         7072    7072    7072
# Campeche                            7441         7441    7441    7441
# Chiapas                            12611        12611   12611   12611
# Chihuahua                          11562        11562   11562   11562
# Ciudad de México                  207714       207714  207714  207714
# Coahuila                           35351        35351   35351   35351
# Colima                              3120         3120    3120    3120
# Durango                            14551        14551   14551   14551
#
#                      ENTIDAD_UM    SEXO  ENTIDAD_RES  MUNICIPIO_RES  \
# ENTIDAD_NAC
# Aguascalientes            10872   10872        10872          10872
# Baja California           14281   14281        14281          14281
# Baja California Sur        7072    7072         7072           7072
# Campeche                   7441    7441         7441           7441
# Chiapas                   12611   12611        12611          12611
# Chihuahua                 11562   11562        11562          11562
# Ciudad de México         207714  207714       207714         207714
# Coahuila                  35351   35351        35351          35351
# Colima                     3120    3120         3120           3120
# Durango                   14551   14551        14551          14551
#
#                      TIPO_PACIENTE  FECHA_INGRESO  ...  CARDIOVASCULAR  \
# ENTIDAD_NAC                                        ...
# Aguascalientes               10872          10872  ...           10872
# Baja California              14281          14281  ...           14281
# Baja California Sur           7072           7072  ...            7072
# Campeche                      7441           7441  ...            7441
# Chiapas                      12611          12611  ...           12611
# Chihuahua                    11562          11562  ...           11562
# Ciudad de México            207714         207714  ...          207714
# Coahuila                     35351          35351  ...           35351
# Colima                        3120           3120  ...            3120
# Durango                      14551          14551  ...           14551
#
#                      OBESIDAD  RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# ENTIDAD_NAC
# Aguascalientes          10872          10872       10872      10872
# Baja California         14281          14281       14281      14281
# Baja California Sur      7072           7072        7072       7072
# Campeche                 7441           7441        7441       7441
# Chiapas                 12611          12611       12611      12611
# Chihuahua               11562          11562       11562      11562
# Ciudad de México       207714         207714      207714     207714
# Coahuila                35351          35351       35351      35351
# Colima                   3120           3120        3120       3120
# Durango                 14551          14551       14551      14551
#
#                      RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  \
# ENTIDAD_NAC
# Aguascalientes           10872     10872              10872        10872
# Baja California          14281     14281              14281        14281
# Baja California Sur       7072      7072               7072         7072
# Campeche                  7441      7441               7441         7441
# Chiapas                  12611     12611              12611        12611
# Chihuahua                11562     11562              11562        11562
# Ciudad de México        207714    207714             207714       207714
# Coahuila                 35351     35351              35351        35351
# Colima                    3120      3120               3120         3120
# Durango                  14551     14551              14551        14551
#
#                         UCI
# ENTIDAD_NAC
# Aguascalientes        10872
# Baja California       14281
# Baja California Sur    7072
# Campeche               7441
# Chiapas               12611
# Chihuahua             11562
# Ciudad de México     207714
# Coahuila              35351
# Colima                 3120
# Durango               14551
#
# [10 rows x 34 columns]

# %%
# preparamos el dataframe para los calculos de agrupación
# Agregamos una nueva columna al dataframe del covid  <<total>> para generar 
# los totales agrupados 

covid["Total"] = 0
covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ... OBESIDAD  \
# 0  No especificado            2              4   Ambulatorio  ...       No
# 1  No especificado           11             20   Ambulatorio  ...       No
# 2  No especificado            9             16   Ambulatorio  ...       No
# 3  No especificado           15             37   Ambulatorio  ...       No
# 4  No especificado           15             37   Ambulatorio  ...       No
#
#   RENAL_CRONICA TABAQUISMO        OTRO_CASO RESULTADO  MIGRANTE  \
# 0            No         No  No especificado  Positivo        99
# 1            No         No  No especificado  Positivo        99
# 2            No         No               Si  Positivo        99
# 3            No         No               No  Positivo        99
# 4            No         No               No  Positivo         2
#
#             PAIS_NACIONALIDAD PAIS_ORIGEN        UCI Total
# 0                 El Salvador          99  No aplica     0
# 1  Estados Unidos de AmÃ©rica          99  No aplica     0
# 2                      Brasil          99  No aplica     0
# 3                     EspaÃ±a          99  No aplica     0
# 4                   Argentina          99  No aplica     0
#
# [5 rows x 36 columns]

# %%
# generamos un nuevo dataframe unicamente con 2 columnas para Simplificar el cálculo 
# Notese la velocidad, al incluir solo 2 columnas genera más rápido el resultado

totalcasos = covid[["ENTIDAD_NAC","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC']).count().head(10)
# Out:
#                       Total
# ENTIDAD_NAC
# Aguascalientes        10872
# Baja California       14281
# Baja California Sur    7072
# Campeche               7441
# Chiapas               12611
# Chihuahua             11562
# Ciudad de México     207714
# Coahuila              35351
# Colima                 3120
# Durango               14551

# %%
# Se puede incluir la función reset_index() para restablecer un nuevo índice
# al dataframe agrupado, y lo convierte en una estructura de datos más adecuada

totalcasos = covid[["ENTIDAD_NAC","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC']).count().reset_index().head()
# Out:
#            ENTIDAD_NAC  Total
# 0       Aguascalientes  10872
# 1      Baja California  14281
# 2  Baja California Sur   7072
# 3             Campeche   7441
# 4              Chiapas  12611

# %% [markdown]
# ### Ejemplo 2
#
# #### Contar cuantas pruebas de COVID se realizaron por estado, desglosado por sexo

# %%
# 2 niveles de agrupamiento

totalcasos = covid[["ENTIDAD_NAC","SEXO","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO"]).count().head(10)
# Out:
#                             Total
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre   4972
#                     Mujer    5900
# Baja California     Hombre   6889
#                     Mujer    7392
# Baja California Sur Hombre   3272
#                     Mujer    3800
# Campeche            Hombre   4130
#                     Mujer    3311
# Chiapas             Hombre   6993
#                     Mujer    5618

# %%
# De la misma forma podemos resetear el indice para generar un dataframe más amigable

totalcasos = covid[["ENTIDAD_NAC","SEXO","Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO"]).count().reset_index().head(10)
# Out:
#            ENTIDAD_NAC    SEXO  Total
# 0       Aguascalientes  Hombre   4972
# 1       Aguascalientes   Mujer   5900
# 2      Baja California  Hombre   6889
# 3      Baja California   Mujer   7392
# 4  Baja California Sur  Hombre   3272
# 5  Baja California Sur   Mujer   3800
# 6             Campeche  Hombre   4130
# 7             Campeche   Mujer   3311
# 8              Chiapas  Hombre   6993
# 9              Chiapas   Mujer   5618

# %% [markdown]
# ### Ejemplo 3
#
# #### Contar cuantas pruebas de COVID se realizaron por estado, desglosado por sexo y tipo  de paciente

# %%
# 2 niveles de agrupamiento

totalcasos = covid[["ENTIDAD_NAC", "SEXO", "TIPO_PACIENTE", "Total"]]  
totalcasos.groupby(['ENTIDAD_NAC',"SEXO", "TIPO_PACIENTE"]).count().head(10)
# Out:
#                                           Total
# ENTIDAD_NAC         SEXO   TIPO_PACIENTE
# Aguascalientes      Hombre Ambulatorio     4139
#                            Hospitalizado    833
#                     Mujer  Ambulatorio     5261
#                            Hospitalizado    639
# Baja California     Hombre Ambulatorio     4761
#                            Hospitalizado   2128
#                     Mujer  Ambulatorio     5942
#                            Hospitalizado   1450
# Baja California Sur Hombre Ambulatorio     2849
#                            Hospitalizado    423

# %%
# De la misma forma, reseteamos el indice

# Agregamos un nivel más de grupos

totalcasos = covid[["ENTIDAD_NAC", "SEXO", "TIPO_PACIENTE", "Total"]]  

totalcasos.groupby(['ENTIDAD_NAC',"SEXO", "TIPO_PACIENTE"]).count().reset_index().head(10)
# Out:
#            ENTIDAD_NAC    SEXO  TIPO_PACIENTE  Total
# 0       Aguascalientes  Hombre    Ambulatorio   4139
# 1       Aguascalientes  Hombre  Hospitalizado    833
# 2       Aguascalientes   Mujer    Ambulatorio   5261
# 3       Aguascalientes   Mujer  Hospitalizado    639
# 4      Baja California  Hombre    Ambulatorio   4761
# 5      Baja California  Hombre  Hospitalizado   2128
# 6      Baja California   Mujer    Ambulatorio   5942
# 7      Baja California   Mujer  Hospitalizado   1450
# 8  Baja California Sur  Hombre    Ambulatorio   2849
# 9  Baja California Sur  Hombre  Hospitalizado    423

# %% [markdown]
# ###  Ejemplo 4
#
# #### Contar el numero de casos por día

# %%
totalcasos = covid[ ["FECHA_INGRESO", "Total"] ]
totalcasos.head()
# Out:
#   FECHA_INGRESO  Total
# 0    18/04/2020      0
# 1    18/06/2020      0
# 2    15/03/2020      0
# 3    20/03/2020      0
# 4    02/05/2020      0

# %%
# El resultado que arroja es correcto el calculo, pero lo que esta mal es que 
# el tipo de dato es como texto y por eso no hay un orden cronológico
#  tenemos que convertir a tipo de dato **datetime**

totalcasos.groupby(["FECHA_INGRESO"]).count().reset_index().head(10)
# Out:
#   FECHA_INGRESO  Total
# 0    01/01/2020      5
# 1    01/02/2020      8
# 2    01/03/2020     29
# 3    01/04/2020   1593
# 4    01/05/2020   3074
# 5    01/06/2020  10771
# 6    01/07/2020  15219
# 7    02/01/2020     16
# 8    02/02/2020     12
# 9    02/03/2020     78

# %%
# Notese que la columna FECHA_INGRESO es de tipo object 

covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: int64(8), object(28)
# memory usage: 270.3+ MB

# %%
# Convertimos a datetime la columna FECHA_INGRESO

covid['FECHA_INGRESO'] = pd.to_datetime(covid['FECHA_INGRESO'], format="%d/%m/%Y")

# %%
# Volvemos a verificar y ya esta el cambio

covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(27)
# memory usage: 270.3+ MB

# %%
totalcasos = covid[ ["FECHA_INGRESO", "Total"] ]
totalcasos = totalcasos.groupby( ["FECHA_INGRESO"] ).count().reset_index()
totalcasos.head(10)
# Out:
#   FECHA_INGRESO  Total
# 0    2020-01-01      5
# 1    2020-01-02     16
# 2    2020-01-03     18
# 3    2020-01-04      6
# 4    2020-01-05     14
# 5    2020-01-06     28
# 6    2020-01-07     28
# 7    2020-01-08     15
# 8    2020-01-09     44
# 9    2020-01-10     39

# %%
totalcasos.tail(10)
# Out:
#     FECHA_INGRESO  Total
# 203    2020-07-22  16150
# 204    2020-07-23  15579
# 205    2020-07-24  15237
# 206    2020-07-25   6881
# 207    2020-07-26   4720
# 208    2020-07-27  14753
# 209    2020-07-28  13205
# 210    2020-07-29  12769
# 211    2020-07-30  11635
# 212    2020-07-31    853

# %%
# Apartir del calculo generado anteriormente , podemos graficar la evolución de
# casos covid por dia

totalcasos.set_index("FECHA_INGRESO", inplace = True)
totalcasos
# Out:
#                Total
# FECHA_INGRESO
# 2020-01-01         5
# 2020-01-02        16
# 2020-01-03        18
# 2020-01-04         6
# 2020-01-05        14
# ...              ...
# 2020-07-27     14753
# 2020-07-28     13205
# 2020-07-29     12769
# 2020-07-30     11635
# 2020-07-31       853
#
# [213 rows x 1 columns]

# %%
totalcasos.plot.line()
# Out:
# <AxesSubplot:xlabel='FECHA_INGRESO'>

# %% [markdown]
# ### Ejemplo 5
#
# #### Contar los que dieron positivo a la prueba COVID, y que tienen diabetes e hipertensión, desglosado por entidad

# %%
# Primero especificamos los criterios de seleccion de los registros, luego
# en la proyeccion indicamos las columnas a mostrar y ahi aplicamos la funcion group by

PruebasDgo = covid[ ( covid['RESULTADO'] == "Positivo") &
                ( covid['DIABETES'] == "Si") & 
                ( covid['HIPERTENSION'] == "Si")] [["ENTIDAD_NAC","Total"]].groupby("ENTIDAD_NAC").count().reset_index() 
PruebasDgo.head(10)
# Out:
#            ENTIDAD_NAC  Total
# 0       Aguascalientes    315
# 1      Baja California    909
# 2  Baja California Sur    193
# 3             Campeche    383
# 4              Chiapas    731
# 5            Chihuahua    496
# 6     Ciudad de México   5457
# 7             Coahuila    777
# 8               Colima    145
# 9              Durango    398

# %%
PruebasDgo.set_index("ENTIDAD_NAC", inplace = True)

# %%
PruebasDgo.sort_values("Total")
# Out:
#                      Total
# ENTIDAD_NAC
# No especificado         49
# Colima                 145
# Baja California Sur    193
# Quintana Roo           198
# Aguascalientes         315
# Queretaro              325
# Campeche               383
# Durango                398
# Morelos                409
# Nayarit                419
# Tlaxcala               424
# Zacatecas              435
# Chihuahua              496
# Chiapas                731
# Coahuila               777
# Hidalgo                793
# Yucatan                864
# San Luis Potosí        882
# Baja California        909
# Oaxaca                 943
# Nuevo León             995
# Michoacan             1019
# Tamaulipas            1161
# Guerrero              1248
# Jalisco               1530
# Sinaloa               1603
# Puebla                1725
# Sonora                1776
# Tabasco               1875
# Guanajuato            1885
# Veracruz              2771
# México                3189
# Ciudad de México      5457

# %%
PruebasDgo.sort_values("Total").tail(5).plot.barh()
# Out:
# <AxesSubplot:ylabel='ENTIDAD_NAC'>

# %% [markdown]
# ### Ejemplos con el archivo DiagnosticoIMCOcsv

# %%
DiagnosticoIMCO = pd.read_csv("DiagnosticoIMCOcsv.csv")

DiagnosticoIMCO.head(10)
# Out:
#              Estado  AportacionesFederales  ParticipacionesFederales  \
# 0    Aguascalientes            10676000000                7158000000
# 1        Guanajuato            30265000000               29097000000
# 2         Queretaro            12321000000               11162000000
# 3   San Luis Potosi            20428000000               13656000000
# 4         Zacatecas            14101000000                7903000000
# 5  Ciudad de México            16205000000               68270000000
# 6  Estado de México            77925000000               97088000000
# 7           Morelos            12967000000                9668000000
# 8          Coahuila            17367000000               15930000000
# 9        Nuevo León            24371000000               31371000000
#
#    RecaudacionImpuestos        Region
# 0            1232000000  Centro-Norte
# 1            4373000000  Centro-Norte
# 2            2852000000  Centro-Norte
# 3            1937000000  Centro-Norte
# 4            1192000000  Centro-Norte
# 5           58800000000    Centro-Sur
# 6           21451000000    Centro-Sur
# 7             632000000    Centro-Sur
# 8            2753000000       Noreste
# 9           10579000000       Noreste

# %%
# Verificar que en el tipo de dato sea int64
DiagnosticoIMCO.dtypes
# Out:
# Estado                      object
# AportacionesFederales        int64
# ParticipacionesFederales     int64
# RecaudacionImpuestos         int64
# Region                      object
# dtype: object

# %%
# Agregamos una columna total para ahi generar el calculo

DiagnosticoIMCO["Total"] = 0
DiagnosticoIMCO.head()
# Out:
#             Estado  AportacionesFederales  ParticipacionesFederales  \
# 0   Aguascalientes            10676000000                7158000000
# 1       Guanajuato            30265000000               29097000000
# 2        Queretaro            12321000000               11162000000
# 3  San Luis Potosi            20428000000               13656000000
# 4        Zacatecas            14101000000                7903000000
#
#    RecaudacionImpuestos        Region  Total
# 0            1232000000  Centro-Norte      0
# 1            4373000000  Centro-Norte      0
# 2            2852000000  Centro-Norte      0
# 3            1937000000  Centro-Norte      0
# 4            1192000000  Centro-Norte      0

# %%
# calculamos la recuadación de impuestos por Region

totalReg = DiagnosticoIMCO[["Region", "RecaudacionImpuestos", "Total"]]  

total2 = totalReg.groupby(['Region'])['RecaudacionImpuestos'].sum().reset_index()

# %%
total2
# Out:
#          Region  RecaudacionImpuestos
# 0  Centro-Norte           11586000000
# 1    Centro-Sur           80883000000
# 2       Noreste           17825000000
# 3      Noroeste           18900000000
# 4         Oeste            5533000000
# 5       Oriente           11553000000
# 6      SurOeste            4198000000
# 7       Sureste            9585000000

# %%
# Aplicar formato al dataframe con separador de miles 
total2["RecaudacionImpuestos"] = total2["RecaudacionImpuestos"].astype(float).apply(lambda x: f'{x:,.2f}')

# %%
total2
# Out:
#          Region RecaudacionImpuestos
# 0  Centro-Norte    11,586,000,000.00
# 1    Centro-Sur    80,883,000,000.00
# 2       Noreste    17,825,000,000.00
# 3      Noroeste    18,900,000,000.00
# 4         Oeste     5,533,000,000.00
# 5       Oriente    11,553,000,000.00
# 6      SurOeste     4,198,000,000.00
# 7       Sureste     9,585,000,000.00

# %%
total2.dtypes
# Out:
# Region                  object
# RecaudacionImpuestos    object
# dtype: object

# %% [markdown]
# ###  5.9.1 Ejercicio de Group By      <a id='id91'> </a>
#
# 1. Calcular cuantas pruebas se realizaron por edad
# 2. Mostrar por Sexo los resultados obtenidos por la prueba COVID
# 3. Mostrar el detalle de la situacion de la DIABETES de las personas que dieron positivo desglosado por sexo
# 4. Mostrar el detalle de la situacion de TIPO_PACIENTE de las personas que dieron positivo desglosado por sexo
# 5. Generar un reporte que muestre el número de defunciones desglozado por estado y sexo

# %% [markdown]
# ### Ejercicio 1
#
# - Calcular cuantas pruebas se realizaron por edad

# %%
PruebasDgo = covid[["EDAD","Total"]].groupby("EDAD").count().reset_index() 
PruebasDgo.head()
# Out:
#    EDAD  Total
# 0     0   4128
# 1     1   3119
# 2     2   1913
# 3     3   1650
# 4     4   1688

# %% [markdown]
# ###  Segmentacion de datos por  edades
#
# - Se usa la funcion **cut** de pandas
# - Usar **cut** cuando se desea segmentar y ordenar valores de datos en contenedores.
# - Esta función también es útil para **pasar de una variable continua a una variable categórica**.
# - Por ejemplo, cortar podría **convertir edades en grupos de rangos de edad**.
# - Admite el agrupamiento en un número igual de contenedores o en una matriz de contenedores especificada previamente.

# %%
bins = [-1, 9, 19, 29, 39, 49, 59, 69, 79, 89, 99, 130]

# %%
names = ["0-9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-9", "70-79", "80-89", "90-99", "+100"]

# %%
PruebasDgo["EDAD"] = pd.cut(PruebasDgo["EDAD"], bins, labels = names)

# %%
PruebasDgo.head(12)
# Out:
#      EDAD  Total
# 0     0-9   4128
# 1     0-9   3119
# 2     0-9   1913
# 3     0-9   1650
# 4     0-9   1688
# 5     0-9   1585
# 6     0-9   1690
# 7     0-9   1637
# 8     0-9   1743
# 9     0-9   1746
# 10  10-19   1923
# 11  10-19   1973

# %%
PruebasDgo = PruebasDgo[["EDAD","Total"]].groupby("EDAD").sum().reset_index()

# %%
PruebasDgo.set_index("EDAD", inplace= True)

# %%
PruebasDgo.plot.barh()
# Out:
# <AxesSubplot:ylabel='EDAD'>

# %% [markdown]
# ## 5.9.2  Aggregación <a id='id92'> </a>
#
# - Una vez que se ha creado el objeto **GroupBy**, hay varios métodos disponibles para realizar un cálculo en los datos agrupados.
# - La API de agregación permite expresar múltiples operaciones de agregación de una manera concisa. El punto de entrada para la agregación es **DataFrame.aggregate() o el alias DataFrame.agg()**.
#
# #### Agregar con múltiples funciones
#
# - Puede pasar **múltiples argumentos de agregación como una lista**.
# - Los resultados de cada una de las funciones pasadas serán una fila en el DataFrame resultante.
# - Estos se nombran naturalmente a partir de la función de agregación.
#
# En muchas situaciones es posible que deseemos dividir el conjunto de datos en grupos y hacer algo con esos grupos. Es posible que deseemos realizar una de las siguientes acciones:
#
# - Calcular una estadística de resumen (o estadísticas) para cada grupo.
# - Calcular sumas o medias de grupos.
# - Calcular los tamaños/conteos de los grupos.
#
# Fuente:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/groupby.html?highlight=filter#aggregation

# %%
DiagnosticoIMCO
# Out:
#                  Estado  AportacionesFederales  ParticipacionesFederales  \
# 0        Aguascalientes            10676000000                7158000000
# 1            Guanajuato            30265000000               29097000000
# 2             Queretaro            12321000000               11162000000
# 3       San Luis Potosi            20428000000               13656000000
# 4             Zacatecas            14101000000                7903000000
# 5      Ciudad de México            16205000000               68270000000
# 6      Estado de México            77925000000               97088000000
# 7               Morelos            12967000000                9668000000
# 8              Coahuila            17367000000               15930000000
# 9            Nuevo León            24371000000               31371000000
# 10           Tamaulipas            24455000000               18993000000
# 11      Baja California            20518000000               19401000000
# 12  Baja California Sur             7173000000                4809000000
# 13            Chihuahua            21653000000               19954000000
# 14              Durango            14759000000                8872000000
# 15              Sinaloa            19339000000               15993000000
# 16               Sonora            16463000000               16251000000
# 17               Colima             6590000000                4248000000
# 18              Jalisco            37228000000               44728000000
# 19            Michoacan            32254000000               21689000000
# 20              Nayarit            10307000000                6414000000
# 21              Hidalgo            23965000000               14016000000
# 22               Puebla            38119000000               29998000000
# 23             Tlaxcala            10111000000                6773000000
# 24             Veracruz            57958000000               41408000000
# 25             Campeche             8835000000                5628000000
# 26         Quintana Roo            11188000000                8834000000
# 27              Tabasco            15017000000               18013000000
# 28              Yucatan            13478000000               10972000000
# 29              Chiapas            48873000000               27819000000
# 30             Guerrero            36913000000               16713000000
# 31               Oaxaca            43196000000               18936000000
#
#     RecaudacionImpuestos        Region  Total
# 0             1232000000  Centro-Norte      0
# 1             4373000000  Centro-Norte      0
# 2             2852000000  Centro-Norte      0
# 3             1937000000  Centro-Norte      0
# 4             1192000000  Centro-Norte      0
# 5            58800000000    Centro-Sur      0
# 6            21451000000    Centro-Sur      0
# 7              632000000    Centro-Sur      0
# 8             2753000000       Noreste      0
# 9            10579000000       Noreste      0
# 10            4493000000       Noreste      0
# 11            4341000000      Noroeste      0
# 12            1112000000      Noroeste      0
# 13            5597000000      Noroeste      0
# 14            1907000000      Noroeste      0
# 15            2280000000      Noroeste      0
# 16            3663000000      Noroeste      0
# 17             841000000         Oeste      0
# 18            1935000000         Oeste      0
# 19            1935000000         Oeste      0
# 20             822000000         Oeste      0
# 21            1365000000       Oriente      0
# 22            4872000000       Oriente      0
# 23             552000000       Oriente      0
# 24            4764000000       Oriente      0
# 25            1663000000       Sureste      0
# 26            3930000000       Sureste      0
# 27            1851000000       Sureste      0
# 28            2141000000       Sureste      0
# 29            1478000000      SurOeste      0
# 30            1249000000      SurOeste      0
# 31            1471000000      SurOeste      0

# %%
DiagnosticoIMCO.groupby("Region").aggregate(np.sum)
# Out:
#               AportacionesFederales  ParticipacionesFederales  \
# Region
# Centro-Norte            87791000000               68976000000
# Centro-Sur             107097000000              175026000000
# Noreste                 66193000000               66294000000
# Noroeste                99905000000               85280000000
# Oeste                   86379000000               77079000000
# Oriente                130153000000               92195000000
# SurOeste               128982000000               63468000000
# Sureste                 48518000000               43447000000
#
#               RecaudacionImpuestos  Total
# Region
# Centro-Norte           11586000000      0
# Centro-Sur             80883000000      0
# Noreste                17825000000      0
# Noroeste               18900000000      0
# Oeste                   5533000000      0
# Oriente                11553000000      0
# SurOeste                4198000000      0
# Sureste                 9585000000      0

# %%
# En el siguiente ejemplo, se aplicara las funciones size, sum y mean a cada una de las columans del dataset

DiagnosticoIMCO.groupby("Region").aggregate( [np.size, np.sum, np.mean] )
# Out:
# C:\Users\jgab\AppData\Local\Temp\ipykernel_20268\349428611.py:3: FutureWarning: ['Estado'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   DiagnosticoIMCO.groupby("Region").aggregate( [np.size, np.sum, np.mean] )
#              AportacionesFederales                              \
#                               size           sum          mean
# Region
# Centro-Norte                     5   87791000000  1.755820e+10
# Centro-Sur                       3  107097000000  3.569900e+10
# Noreste                          3   66193000000  2.206433e+10
# Noroeste                         6   99905000000  1.665083e+10
# Oeste                            4   86379000000  2.159475e+10
# Oriente                          4  130153000000  3.253825e+10
# SurOeste                         3  128982000000  4.299400e+10
# Sureste                          4   48518000000  1.212950e+10
#
#              ParticipacionesFederales                              \
#                                  size           sum          mean
# Region
# Centro-Norte                        5   68976000000  1.379520e+10
# Centro-Sur                          3  175026000000  5.834200e+10
# Noreste                             3   66294000000  2.209800e+10
# Noroeste                            6   85280000000  1.421333e+10
# Oeste                               4   77079000000  1.926975e+10
# Oriente                             4   92195000000  2.304875e+10
# SurOeste                            3   63468000000  2.115600e+10
# Sureste                             4   43447000000  1.086175e+10
#
#              RecaudacionImpuestos                            Total
#                              size          sum          mean  size sum mean
# Region
# Centro-Norte                    5  11586000000  2.317200e+09     5   0  0.0
# Centro-Sur                      3  80883000000  2.696100e+10     3   0  0.0
# Noreste                         3  17825000000  5.941667e+09     3   0  0.0
# Noroeste                        6  18900000000  3.150000e+09     6   0  0.0
# Oeste                           4   5533000000  1.383250e+09     4   0  0.0
# Oriente                         4  11553000000  2.888250e+09     4   0  0.0
# SurOeste                        3   4198000000  1.399333e+09     3   0  0.0
# Sureste                         4   9585000000  2.396250e+09     4   0  0.0

# %%
# Se puede ser más especifico y dar un nombre especifico a cada columna  

DiagnosticoIMCO.groupby("Region").agg(
    Estados = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="size"),
    Minimo = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="min"),
    Maximo = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="max"),
    Total = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="sum"),
    Promedio = pd.NamedAgg(column="RecaudacionImpuestos", aggfunc="mean")
)
# Out:
#               Estados      Minimo       Maximo        Total      Promedio
# Region
# Centro-Norte        5  1192000000   4373000000  11586000000  2.317200e+09
# Centro-Sur          3   632000000  58800000000  80883000000  2.696100e+10
# Noreste             3  2753000000  10579000000  17825000000  5.941667e+09
# Noroeste            6  1112000000   5597000000  18900000000  3.150000e+09
# Oeste               4   822000000   1935000000   5533000000  1.383250e+09
# Oriente             4   552000000   4872000000  11553000000  2.888250e+09
# SurOeste            3  1249000000   1478000000   4198000000  1.399333e+09
# Sureste             4  1663000000   3930000000   9585000000  2.396250e+09

# %%
DiagnosticoIMCO.style.set_caption('Ingresos de los estados')
# Out:
# <style type="text/css">
# </style>
# <table id="T_485e3">
#   <caption>Ingresos de los estados</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_485e3_level0_col0" class="col_heading level0 col0" >Estado</th>
#       <th id="T_485e3_level0_col1" class="col_heading level0 col1" >AportacionesFederales</th>
#       <th id="T_485e3_level0_col2" class="col_heading level0 col2" >ParticipacionesFederales</th>
#       <th id="T_485e3_level0_col3" class="col_heading level0 col3" >RecaudacionImpuestos</th>
#       <th id="T_485e3_level0_col4" class="col_heading level0 col4" >Region</th>
#       <th id="T_485e3_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_485e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_485e3_row0_col0" class="data row0 col0" >Aguascalientes</td>
#       <td id="T_485e3_row0_col1" class="data row0 col1" >10676000000</td>
#       <td id="T_485e3_row0_col2" class="data row0 col2" >7158000000</td>
#       <td id="T_485e3_row0_col3" class="data row0 col3" >1232000000</td>
#       <td id="T_485e3_row0_col4" class="data row0 col4" >Centro-Norte</td>
#       <td id="T_485e3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_485e3_row1_col0" class="data row1 col0" >Guanajuato</td>
#       <td id="T_485e3_row1_col1" class="data row1 col1" >30265000000</td>
#       <td id="T_485e3_row1_col2" class="data row1 col2" >29097000000</td>
#       <td id="T_485e3_row1_col3" class="data row1 col3" >4373000000</td>
#       <td id="T_485e3_row1_col4" class="data row1 col4" >Centro-Norte</td>
#       <td id="T_485e3_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_485e3_row2_col0" class="data row2 col0" >Queretaro</td>
#       <td id="T_485e3_row2_col1" class="data row2 col1" >12321000000</td>
#       <td id="T_485e3_row2_col2" class="data row2 col2" >11162000000</td>
#       <td id="T_485e3_row2_col3" class="data row2 col3" >2852000000</td>
#       <td id="T_485e3_row2_col4" class="data row2 col4" >Centro-Norte</td>
#       <td id="T_485e3_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_485e3_row3_col0" class="data row3 col0" >San Luis Potosi</td>
#       <td id="T_485e3_row3_col1" class="data row3 col1" >20428000000</td>
#       <td id="T_485e3_row3_col2" class="data row3 col2" >13656000000</td>
#       <td id="T_485e3_row3_col3" class="data row3 col3" >1937000000</td>
#       <td id="T_485e3_row3_col4" class="data row3 col4" >Centro-Norte</td>
#       <td id="T_485e3_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_485e3_row4_col0" class="data row4 col0" >Zacatecas</td>
#       <td id="T_485e3_row4_col1" class="data row4 col1" >14101000000</td>
#       <td id="T_485e3_row4_col2" class="data row4 col2" >7903000000</td>
#       <td id="T_485e3_row4_col3" class="data row4 col3" >1192000000</td>
#       <td id="T_485e3_row4_col4" class="data row4 col4" >Centro-Norte</td>
#       <td id="T_485e3_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_485e3_row5_col0" class="data row5 col0" >Ciudad de México</td>
#       <td id="T_485e3_row5_col1" class="data row5 col1" >16205000000</td>
#       <td id="T_485e3_row5_col2" class="data row5 col2" >68270000000</td>
#       <td id="T_485e3_row5_col3" class="data row5 col3" >58800000000</td>
#       <td id="T_485e3_row5_col4" class="data row5 col4" >Centro-Sur</td>
#       <td id="T_485e3_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_485e3_row6_col0" class="data row6 col0" >Estado de México</td>
#       <td id="T_485e3_row6_col1" class="data row6 col1" >77925000000</td>
#       <td id="T_485e3_row6_col2" class="data row6 col2" >97088000000</td>
#       <td id="T_485e3_row6_col3" class="data row6 col3" >21451000000</td>
#       <td id="T_485e3_row6_col4" class="data row6 col4" >Centro-Sur</td>
#       <td id="T_485e3_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_485e3_row7_col0" class="data row7 col0" >Morelos</td>
#       <td id="T_485e3_row7_col1" class="data row7 col1" >12967000000</td>
#       <td id="T_485e3_row7_col2" class="data row7 col2" >9668000000</td>
#       <td id="T_485e3_row7_col3" class="data row7 col3" >632000000</td>
#       <td id="T_485e3_row7_col4" class="data row7 col4" >Centro-Sur</td>
#       <td id="T_485e3_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_485e3_row8_col0" class="data row8 col0" >Coahuila</td>
#       <td id="T_485e3_row8_col1" class="data row8 col1" >17367000000</td>
#       <td id="T_485e3_row8_col2" class="data row8 col2" >15930000000</td>
#       <td id="T_485e3_row8_col3" class="data row8 col3" >2753000000</td>
#       <td id="T_485e3_row8_col4" class="data row8 col4" >Noreste</td>
#       <td id="T_485e3_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_485e3_row9_col0" class="data row9 col0" >Nuevo León</td>
#       <td id="T_485e3_row9_col1" class="data row9 col1" >24371000000</td>
#       <td id="T_485e3_row9_col2" class="data row9 col2" >31371000000</td>
#       <td id="T_485e3_row9_col3" class="data row9 col3" >10579000000</td>
#       <td id="T_485e3_row9_col4" class="data row9 col4" >Noreste</td>
#       <td id="T_485e3_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_485e3_row10_col0" class="data row10 col0" >Tamaulipas</td>
#       <td id="T_485e3_row10_col1" class="data row10 col1" >24455000000</td>
#       <td id="T_485e3_row10_col2" class="data row10 col2" >18993000000</td>
#       <td id="T_485e3_row10_col3" class="data row10 col3" >4493000000</td>
#       <td id="T_485e3_row10_col4" class="data row10 col4" >Noreste</td>
#       <td id="T_485e3_row10_col5" class="data row10 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_485e3_row11_col0" class="data row11 col0" >Baja California</td>
#       <td id="T_485e3_row11_col1" class="data row11 col1" >20518000000</td>
#       <td id="T_485e3_row11_col2" class="data row11 col2" >19401000000</td>
#       <td id="T_485e3_row11_col3" class="data row11 col3" >4341000000</td>
#       <td id="T_485e3_row11_col4" class="data row11 col4" >Noroeste</td>
#       <td id="T_485e3_row11_col5" class="data row11 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_485e3_row12_col0" class="data row12 col0" >Baja California Sur</td>
#       <td id="T_485e3_row12_col1" class="data row12 col1" >7173000000</td>
#       <td id="T_485e3_row12_col2" class="data row12 col2" >4809000000</td>
#       <td id="T_485e3_row12_col3" class="data row12 col3" >1112000000</td>
#       <td id="T_485e3_row12_col4" class="data row12 col4" >Noroeste</td>
#       <td id="T_485e3_row12_col5" class="data row12 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_485e3_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_485e3_row13_col0" class="data row13 col0" >Chihuahua</td>
#       <td id="T_485e3_row13_col1" class="data row13 col1" >21653000000</td>
#       <td id="T_485e3_row13_col2" class="data row13 col2" >19954000000</td>
#       <td id="T_485e3_row13_col3" class="data row13 col3" >5597000000</td>

# %% [markdown]
# ####  Regresamos con la BD de COVID

# %%
covid.head()
# Out:
#   FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM    SEXO  \
# 0          31/07/2020      15f43a  ISSSTE       4           2   Mujer
# 1          31/07/2020      0d6511  ISSSTE       4          11  Hombre
# 2          31/07/2020      0baff6  ISSSTE       9           9   Mujer
# 3          31/07/2020      1b5b75  ISSSTE       9           9   Mujer
# 4          31/07/2020      120290  ISSSTE       9          15   Mujer
#
#        ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES TIPO_PACIENTE  ... OBESIDAD  \
# 0  No especificado            2              4   Ambulatorio  ...       No
# 1  No especificado           11             20   Ambulatorio  ...       No
# 2  No especificado            9             16   Ambulatorio  ...       No
# 3  No especificado           15             37   Ambulatorio  ...       No
# 4  No especificado           15             37   Ambulatorio  ...       No
#
#   RENAL_CRONICA TABAQUISMO        OTRO_CASO RESULTADO  MIGRANTE  \
# 0            No         No  No especificado  Positivo        99
# 1            No         No  No especificado  Positivo        99
# 2            No         No               Si  Positivo        99
# 3            No         No               No  Positivo        99
# 4            No         No               No  Positivo         2
#
#             PAIS_NACIONALIDAD PAIS_ORIGEN        UCI Total
# 0                 El Salvador          99  No aplica     0
# 1  Estados Unidos de AmÃ©rica          99  No aplica     0
# 2                      Brasil          99  No aplica     0
# 3                     EspaÃ±a          99  No aplica     0
# 4                   Argentina          99  No aplica     0
#
# [5 rows x 36 columns]

# %%
# Para el siguiente ejercicio vamos a Mostrar la edad minima, maxima y promedio por # de los que fallecieron
# Primero verificamos la informacion en general 

totalcasos = covid[ covid["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "EDAD","Total"]]
totalcasos
# Out:
#             ENTIDAD_NAC  EDAD  Total
# 13      No especificado    74      0
# 178     No especificado    57      0
# 196     No especificado    60      0
# 199     No especificado    50      0
# 364     No especificado    35      0
# ...                 ...   ...    ...
# 984204        Zacatecas    89      0
# 984225        Zacatecas    78      0
# 984228        Zacatecas    74      0
# 984239        Zacatecas    60      0
# 984258        Zacatecas    70      0
#
# [60247 rows x 3 columns]

# %%
# Ahora si Mostramos la edad minima, maxima y promedio por ESTADO de los que fallecieron

totalcasos = covid[ covid["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "EDAD"]]
totalcasos.groupby(["ENTIDAD_NAC"]).agg(['min', 'max', 'mean']).head(15)
# Out:
#                     EDAD
#                      min  max       mean
# ENTIDAD_NAC
# Aguascalientes         0  100  60.790831
# Baja California        0  102  58.260642
# Baja California Sur    1   96  62.068182
# Campeche               0   99  62.072897
# Chiapas                0   94  61.575281
# Chihuahua              0  101  60.602388
# Ciudad de México       0  100  59.831533
# Coahuila               0   99  61.739666
# Colima                 0   95  63.975369
# Durango                0   98  63.960983
# Guanajuato             0   99  64.507042
# Guerrero               0   99  63.404538
# Hidalgo                0   96  61.795845
# Jalisco                0  100  63.094970
# Michoacan              0  101  64.515577

# %%
# Agregamos el SEXO

totalcasos = covid[ covid["FECHA_DEF"] !="9999-99-99"] [["ENTIDAD_NAC", "SEXO", "EDAD"]]
totalcasos.groupby(["ENTIDAD_NAC", "SEXO"]).agg(['min', 'max', 'mean']).head(15)
# Out:
#                            EDAD
#                             min  max       mean
# ENTIDAD_NAC         SEXO
# Aguascalientes      Hombre    0  100  59.351759
#                     Mujer     0   95  62.700000
# Baja California     Hombre    0   98  57.452174
#                     Mujer     0  102  59.485997
# Baja California Sur Hombre    3   96  59.040000
#                     Mujer     1   92  66.052632
# Campeche            Hombre    0   99  62.420588
#                     Mujer     0   99  61.466667
# Chiapas             Hombre    0   94  61.898901
#                     Mujer     0   94  60.882353
# Chihuahua           Hombre    0  100  59.088785
#                     Mujer     0  101  62.776286
# Ciudad de México    Hombre    0  100  59.018879
#                     Mujer     0   99  61.594438
# Coahuila            Hombre    0   93  61.570988

# %% [markdown]
# ## 5.10 Merge Dataframes     <a id='id10'> </a>
#
# - **pandas** tiene operaciones de **combinación de dataframes** en memoria de alto rendimiento muy similares a las bases de datos relacionales como SQL.
# - **pandas** proporciona una sola función, **merge()**, como punto de entrada para todas las operaciones de combinación de bases de datos entre DataFrames.
#
# Las operaciones de combinación entre dos DataFrames se debe considerar lo siguiente:
#
# - **Uniones uno a uno**: por ejemplo, cuando se unen dos objetos DataFrame en sus índices (que deben contener valores únicos).
# - **Uniones de muchos a uno**: por ejemplo, cuando se une un índice (único) a una o más columnas en un DataFrame diferente.
# - **Uniones de muchos a muchos** : unión de columnas sobre columnas!
#
# ### how
# - El argumento **how** para fusionar los dataframes sirve para determinar qué claves se incluirán en la tabla resultante.
# - Si una combinación de índices (keys) no aparece en las tablas izquierda o derecha, los valores en la tabla unida serán NA.
#
# ![](PandasMerge.png)

# %%
# Abrimos el catalogo de sexos del archivo de ctalogos de excel en la hoja adecuada

df_catalogo_sexo = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo SEXO' )
df_catalogo_sexo
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1            MUJER
# 1      2           HOMBRE
# 2     99  NO ESPECIFICADO

# %%
#df_catalogo_sector = pd.read_excel('Catalogos_covid.xlsx',
#                       sheet_name = 'Catálogo SEXO',
#                      skiprows =range(20),
#                      skipfooter=2 )

df_catalogo_sexo = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo SEXO' )
df_catalogo_sexo
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1            MUJER
# 1      2           HOMBRE
# 2     99  NO ESPECIFICADO

# %%
df_catalogo_tipopaciente = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo TIPO_PACIENTE' )
df_catalogo_tipopaciente
# Out:
#    CLAVE      DESCRIPCIÓN
# 0      1      AMBULATORIO
# 1      2    HOSPITALIZADO
# 2     99  NO ESPECIFICADO

# %%
df_catalogo_entidades = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo de ENTIDADES' )
df_catalogo_entidades.head()
# Out:
#    CLAVE_ENTIDAD    ENTIDAD_FEDERATIVA ABREVIATURA
# 0              1        AGUASCALIENTES          AS
# 1              2       BAJA CALIFORNIA          BC
# 2              3   BAJA CALIFORNIA SUR          BS
# 3              4              CAMPECHE          CC
# 4              5  COAHUILA DE ZARAGOZA          CL

# %%
df_catalogo_resultado = pd.read_excel('Catalogos_covid.xlsx',
                       sheet_name = 'Catálogo RESULTADO' )
df_catalogo_resultado.head()
# Out:
#    CLAVE             DESCRIPCIÓN
# 0      1     Positivo SARS-CoV-2
# 1      2  No positivo SARS-CoV-2
# 2      3     Resultado pendiente

# %%
covid2 = pd.read_csv("20-07-31-COVID19MEXICO.csv", encoding = 'ISO-8859-1')
covid2
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      01cd82       2       3          27     2
# 2               2020-07-31      16c05d       2       3          15     2
# 3               2020-07-31      106446       2       4          15     2
# 4               2020-07-31      1162db       2       4           9     1
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      125bb4       2      12          15     1
# 984284          2020-07-31      02101b       2      12          28     2
# 984285          2020-07-31      0f4797       2      12          25     1
# 984286          2020-07-31      13346d       2       9           8     1
# 984287          2020-07-31      16a42d       2      12          16     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                27           27              4              1  ...
# 2                15           15             24              1  ...
# 3                15           15            121              2  ...
# 4                15           15             58              1  ...
# ...             ...          ...            ...            ...  ...
# 984283           15           15             27              1  ...
# 984284           28           28             27              1  ...
# 984285           25           25             12              1  ...
# 984286            8            8             17              1  ...
# 984287           16           16             53              1  ...
#
#        CARDIOVASCULAR OBESIDAD RENAL_CRONICA  TABAQUISMO  OTRO_CASO  \
# 0                   2        2             2           1          1
# 1                   2        2             2           2          1
# 2                   1        2             2           2          1
# 3                   2        2             2           2         99
# 4                   2        2             2           2         99
# ...               ...      ...           ...         ...        ...
# 984283              2        1             2           2         99
# 984284              2        2             2           1          1
# 984285              2        2             2           2          2
# 984286              2        2             2           2          2
# 984287              2        2             2           2          2
#
#         RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI
# 0               1        99            MÃ©xico           99   97
# 1               1        99            MÃ©xico           99   97
# 2               1        99            MÃ©xico           99   97
# 3               1        99            MÃ©xico           99    2
# 4               1        99            MÃ©xico           99   97
# ...           ...       ...                ...          ...  ...
# 984283          3        99            MÃ©xico           99   97
# 984284          3        99            MÃ©xico           99   97
# 984285          3        99            MÃ©xico           99   97
# 984286          3        99            MÃ©xico           99   97
# 984287          3        99            MÃ©xico           99   97
#
# [984288 rows x 35 columns]

# %%
# Hacemos el JOIN especificando las columnas en comun que permitira hacer el JOIN

covidMERGE = pd.merge(covid2, df_catalogo_entidades, left_on="ENTIDAD_NAC",
                  right_on="CLAVE_ENTIDAD")

# %%
# visualizamos el resultado.  Ahora son 38 columnas 
# Las columnas nuevas estan al final 

covidMERGE
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      16c05d       2       3          15     2
# 2               2020-07-31      106446       2       4          15     2
# 3               2020-07-31      1162db       2       4           9     1
# 4               2020-07-31      04b5e9       2       4          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      038942       2       9           8     2
# 984284          2020-07-31      18aec3       2      12           1     2
# 984285          2020-07-31      05b498       2       6          32     1
# 984286          2020-07-31      18cec8       2       6          32     2
# 984287          2020-07-31      0305fe       2      12           1     2
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                15           15             24              1  ...
# 2                15           15            121              2  ...
# 3                15           15             58              1  ...
# 4                15           15             62              2  ...
# ...             ...          ...            ...            ...  ...
# 984283           32            8             19              1  ...
# 984284           32            1              1              1  ...
# 984285           32           32             51              1  ...
# 984286           32           32             37              1  ...
# 984287           32            1              1              1  ...
#
#        TABAQUISMO OTRO_CASO RESULTADO  MIGRANTE  PAIS_NACIONALIDAD  \
# 0               1         1         1        99            MÃ©xico
# 1               2         1         1        99            MÃ©xico
# 2               2        99         1        99            MÃ©xico
# 3               2        99         1        99            MÃ©xico
# 4               2        99         1        99            MÃ©xico
# ...           ...       ...       ...       ...                ...
# 984283          2         2         3        99            MÃ©xico
# 984284          2         1         3        99            MÃ©xico
# 984285          2         2         3        99            MÃ©xico
# 984286          2         2         3        99            MÃ©xico
# 984287          2         1         3        99            MÃ©xico
#
#         PAIS_ORIGEN  UCI  CLAVE_ENTIDAD  ENTIDAD_FEDERATIVA  ABREVIATURA
# 0                99   97             15              MÉXICO           MC
# 1                99   97             15              MÉXICO           MC
# 2                99    2             15              MÉXICO           MC
# 3                99   97             15              MÉXICO           MC
# 4                99    2             15              MÉXICO           MC
# ...             ...  ...            ...                 ...          ...
# 984283           99   97             32           ZACATECAS           ZS
# 984284           99   97             32           ZACATECAS           ZS
# 984285           99   97             32           ZACATECAS           ZS
# 984286           99   97             32           ZACATECAS           ZS
# 984287           99   97             32           ZACATECAS           ZS
#
# [984288 rows x 38 columns]

# %%
covidMERGE.columns
# Out:
# Index(['FECHA_ACTUALIZACION', 'ID_REGISTRO', 'ORIGEN', 'SECTOR', 'ENTIDAD_UM',
#        'SEXO', 'ENTIDAD_NAC', 'ENTIDAD_RES', 'MUNICIPIO_RES', 'TIPO_PACIENTE',
#        'FECHA_INGRESO', 'FECHA_SINTOMAS', 'FECHA_DEF', 'INTUBADO', 'NEUMONIA',
#        'EDAD', 'NACIONALIDAD', 'EMBARAZO', 'HABLA_LENGUA_INDIG', 'DIABETES',
#        'EPOC', 'ASMA', 'INMUSUPR', 'HIPERTENSION', 'OTRA_COM',
#        'CARDIOVASCULAR', 'OBESIDAD', 'RENAL_CRONICA', 'TABAQUISMO',
#        'OTRO_CASO', 'RESULTADO', 'MIGRANTE', 'PAIS_NACIONALIDAD',
#        'PAIS_ORIGEN', 'UCI', 'CLAVE_ENTIDAD', 'ENTIDAD_FEDERATIVA',
#        'ABREVIATURA'],
#       dtype='object')

# %%
# verificamos la informacion del nuevo dataframe con las columnas agregadas
# son 984288 registros, 38 columnas y ocupa un espacio en memoria de 292.9+ MB

covidMERGE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984288 entries, 0 to 984287
# Data columns (total 38 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  int64
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  int64
#  6   ENTIDAD_NAC          984288 non-null  int64
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  int64
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  int64
#  14  NEUMONIA             984288 non-null  int64
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  int64
#  18  HABLA_LENGUA_INDIG   984288 non-null  int64
#  19  DIABETES             984288 non-null  int64
#  20  EPOC                 984288 non-null  int64
#  21  ASMA                 984288 non-null  int64
#  22  INMUSUPR             984288 non-null  int64
#  23  HIPERTENSION         984288 non-null  int64
#  24  OTRA_COM             984288 non-null  int64
#  25  CARDIOVASCULAR       984288 non-null  int64
#  26  OBESIDAD             984288 non-null  int64
#  27  RENAL_CRONICA        984288 non-null  int64
#  28  TABAQUISMO           984288 non-null  int64
#  29  OTRO_CASO            984288 non-null  int64
#  30  RESULTADO            984288 non-null  int64
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  int64
#  35  CLAVE_ENTIDAD        984288 non-null  int64
#  36  ENTIDAD_FEDERATIVA   984288 non-null  object
#  37  ABREVIATURA          984288 non-null  object
# dtypes: int64(29), object(9)
# memory usage: 292.9+ MB

# %%
# Ahora hacemos la union con el catalogo de sexo
# Nuevamente se agregan más columnas


covidMERGE = pd.merge(covidMERGE,  df_catalogo_sexo, left_on="SEXO",
                  right_on="CLAVE")
covidMERGE
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      16c05d       2       3          15     2
# 2               2020-07-31      106446       2       4          15     2
# 3               2020-07-31      04b5e9       2       4          15     2
# 4               2020-07-31      116171       2       4          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      06451f       1       4          32     1
# 984284          2020-07-31      09010e       1      12          32     1
# 984285          2020-07-31      18ac50       1       4          32     1
# 984286          2020-07-31      090de0       1      12          32     1
# 984287          2020-07-31      05b498       2       6          32     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ... RESULTADO  \
# 0                15           15            118              1  ...         1
# 1                15           15             24              1  ...         1
# 2                15           15            121              2  ...         1
# 3                15           15             62              2  ...         1
# 4                15           15             60              1  ...         1
# ...             ...          ...            ...            ...  ...       ...
# 984283           32           32             42              1  ...         3
# 984284           32           32             56              2  ...         3
# 984285           32           32             40              1  ...         3
# 984286           32           32             40              1  ...         3
# 984287           32           32             51              1  ...         3
#
#        MIGRANTE PAIS_NACIONALIDAD  PAIS_ORIGEN  UCI  CLAVE_ENTIDAD  \
# 0            99           MÃ©xico           99   97             15
# 1            99           MÃ©xico           99   97             15
# 2            99           MÃ©xico           99    2             15
# 3            99           MÃ©xico           99    2             15
# 4            99           MÃ©xico           99   97             15
# ...         ...               ...          ...  ...            ...
# 984283       99           MÃ©xico           99   97             32
# 984284       99           MÃ©xico           99    1             32
# 984285       99           MÃ©xico           99   97             32
# 984286       99           MÃ©xico           99   97             32
# 984287       99           MÃ©xico           99   97             32
#
#         ENTIDAD_FEDERATIVA  ABREVIATURA  CLAVE  DESCRIPCIÓN
# 0                   MÉXICO           MC      2       HOMBRE
# 1                   MÉXICO           MC      2       HOMBRE
# 2                   MÉXICO           MC      2       HOMBRE
# 3                   MÉXICO           MC      2       HOMBRE
# 4                   MÉXICO           MC      2       HOMBRE
# ...                    ...          ...    ...          ...
# 984283           ZACATECAS           ZS      1        MUJER
# 984284           ZACATECAS           ZS      1        MUJER
# 984285           ZACATECAS           ZS      1        MUJER
# 984286           ZACATECAS           ZS      1        MUJER
# 984287           ZACATECAS           ZS      1        MUJER
#
# [984288 rows x 40 columns]

# %%
# Al verificar el espacio vemos que ahora tiene 307.9+ MB

covidMERGE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984288 entries, 0 to 984287
# Data columns (total 40 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  int64
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  int64
#  6   ENTIDAD_NAC          984288 non-null  int64
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  int64
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  int64
#  14  NEUMONIA             984288 non-null  int64
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  int64
#  18  HABLA_LENGUA_INDIG   984288 non-null  int64
#  19  DIABETES             984288 non-null  int64
#  20  EPOC                 984288 non-null  int64
#  21  ASMA                 984288 non-null  int64
#  22  INMUSUPR             984288 non-null  int64
#  23  HIPERTENSION         984288 non-null  int64
#  24  OTRA_COM             984288 non-null  int64
#  25  CARDIOVASCULAR       984288 non-null  int64
#  26  OBESIDAD             984288 non-null  int64
#  27  RENAL_CRONICA        984288 non-null  int64
#  28  TABAQUISMO           984288 non-null  int64
#  29  OTRO_CASO            984288 non-null  int64
#  30  RESULTADO            984288 non-null  int64
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  int64
#  35  CLAVE_ENTIDAD        984288 non-null  int64
#  36  ENTIDAD_FEDERATIVA   984288 non-null  object
#  37  ABREVIATURA          984288 non-null  object
#  38  CLAVE                984288 non-null  int64
#  39  DESCRIPCIÓN          984288 non-null  object
# dtypes: int64(30), object(10)
# memory usage: 307.9+ MB

# %%
# Ahora hacemos la union con el catalogo de tipo paciente

covidMERGE = pd.merge(covidMERGE,  df_catalogo_tipopaciente, left_on="TIPO_PACIENTE",
                  right_on="CLAVE")
covidMERGE
# Out:
#        FECHA_ACTUALIZACION ID_REGISTRO  ORIGEN  SECTOR  ENTIDAD_UM  SEXO  \
# 0               2020-07-31      1765cb       2       3          15     2
# 1               2020-07-31      16c05d       2       3          15     2
# 2               2020-07-31      116171       2       4          15     2
# 3               2020-07-31      0fa3df       2       3          15     2
# 4               2020-07-31      00fb4d       2       4          15     2
# ...                    ...         ...     ...     ...         ...   ...
# 984283          2020-07-31      147d41       1       4          32     1
# 984284          2020-07-31      11b486       2       4          14     1
# 984285          2020-07-31      0fff21       1       4          32     1
# 984286          2020-07-31      118a72       2      12          10     1
# 984287          2020-07-31      09010e       1      12          32     1
#
#         ENTIDAD_NAC  ENTIDAD_RES  MUNICIPIO_RES  TIPO_PACIENTE  ...  \
# 0                15           15            118              1  ...
# 1                15           15             24              1  ...
# 2                15           15             60              1  ...
# 3                15           15            115              1  ...
# 4                15           15             33              1  ...
# ...             ...          ...            ...            ...  ...
# 984283           32           32             10              2  ...
# 984284           32           14             98              2  ...
# 984285           32           32             42              2  ...
# 984286           32           10              5              2  ...
# 984287           32           32             56              2  ...
#
#        PAIS_NACIONALIDAD PAIS_ORIGEN UCI  CLAVE_ENTIDAD  ENTIDAD_FEDERATIVA  \
# 0                MÃ©xico          99  97             15              MÉXICO
# 1                MÃ©xico          99  97             15              MÉXICO
# 2                MÃ©xico          99  97             15              MÉXICO
# 3                MÃ©xico          99  97             15              MÉXICO
# 4                MÃ©xico          99  97             15              MÉXICO
# ...                  ...         ...  ..            ...                 ...
# 984283           MÃ©xico          99   2             32           ZACATECAS
# 984284           MÃ©xico          99   2             32           ZACATECAS
# 984285           MÃ©xico          99   2             32           ZACATECAS
# 984286           MÃ©xico          99   2             32           ZACATECAS
# 984287           MÃ©xico          99   1             32           ZACATECAS
#
#         ABREVIATURA  CLAVE_x  DESCRIPCIÓN_x  CLAVE_y  DESCRIPCIÓN_y
# 0                MC        2         HOMBRE        1    AMBULATORIO
# 1                MC        2         HOMBRE        1    AMBULATORIO
# 2                MC        2         HOMBRE        1    AMBULATORIO
# 3                MC        2         HOMBRE        1    AMBULATORIO
# 4                MC        2         HOMBRE        1    AMBULATORIO
# ...             ...      ...            ...      ...            ...
# 984283           ZS        1          MUJER        2  HOSPITALIZADO
# 984284           ZS        1          MUJER        2  HOSPITALIZADO
# 984285           ZS        1          MUJER        2  HOSPITALIZADO
# 984286           ZS        1          MUJER        2  HOSPITALIZADO
# 984287           ZS        1          MUJER        2  HOSPITALIZADO
#
# [984288 rows x 42 columns]

# %%
# NUevamente, verificar el espacio vemos que ahora tiene 322.9+ MB y 42 columnas

covidMERGE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984288 entries, 0 to 984287
# Data columns (total 42 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  int64
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  int64
#  6   ENTIDAD_NAC          984288 non-null  int64
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  int64
#  10  FECHA_INGRESO        984288 non-null  object
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  int64
#  14  NEUMONIA             984288 non-null  int64
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  int64
#  18  HABLA_LENGUA_INDIG   984288 non-null  int64
#  19  DIABETES             984288 non-null  int64
#  20  EPOC                 984288 non-null  int64
#  21  ASMA                 984288 non-null  int64
#  22  INMUSUPR             984288 non-null  int64
#  23  HIPERTENSION         984288 non-null  int64
#  24  OTRA_COM             984288 non-null  int64
#  25  CARDIOVASCULAR       984288 non-null  int64
#  26  OBESIDAD             984288 non-null  int64
#  27  RENAL_CRONICA        984288 non-null  int64
#  28  TABAQUISMO           984288 non-null  int64
#  29  OTRO_CASO            984288 non-null  int64
#  30  RESULTADO            984288 non-null  int64
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  int64
#  35  CLAVE_ENTIDAD        984288 non-null  int64
#  36  ENTIDAD_FEDERATIVA   984288 non-null  object
#  37  ABREVIATURA          984288 non-null  object
#  38  CLAVE_x              984288 non-null  int64
#  39  DESCRIPCIÓN_x        984288 non-null  object
#  40  CLAVE_y              984288 non-null  int64
#  41  DESCRIPCIÓN_y        984288 non-null  object
# dtypes: int64(31), object(11)
# memory usage: 322.9+ MB

# %%
#  Para ahorrar espacio en memoria vamos a borrar las columnas que ya no necesitamos
# Primero hacemos una lista d elos nobres de columnas a borrar

columnas = ["FECHA_ACTUALIZACION", "ID_REGISTRO", "TIPO_PACIENTE", "ORIGEN", "SECTOR", "ENTIDAD_UM", "SEXO", "ENTIDAD_RES", 
            "MUNICIPIO_RES", "HABLA_LENGUA_INDIG", "OTRA_COM", "OTRO_CASO", "MIGRANTE", "PAIS_ORIGEN",
           "CLAVE_ENTIDAD", "ABREVIATURA", "CLAVE_x", "CLAVE_y"]

# %%
# Borramos las columnas y mostramos el resultado

covidMERGE.drop(columnas, axis = 1, inplace = True)
covidMERGE
# Out:
#         ENTIDAD_NAC FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  \
# 0                15    2020-06-12     2020-06-08  9999-99-99        97
# 1                15    2020-06-20     2020-06-20  9999-99-99        97
# 2                15    2020-04-15     2020-04-05  9999-99-99        97
# 3                15    2020-06-15     2020-06-10  9999-99-99        97
# 4                15    2020-04-27     2020-04-27  9999-99-99        97
# ...             ...           ...            ...         ...       ...
# 984283           32    2020-07-27     2020-07-23  9999-99-99         2
# 984284           32    2020-07-30     2020-07-26  9999-99-99         2
# 984285           32    2020-07-28     2020-07-25  9999-99-99         2
# 984286           32    2020-07-06     2020-07-06  9999-99-99         2
# 984287           32    2020-07-30     2020-07-25  9999-99-99         2
#
#         NEUMONIA  EDAD  NACIONALIDAD  EMBARAZO  DIABETES  ...  CARDIOVASCULAR  \
# 0              2    32             1        97         2  ...               2
# 1              2    53             1        97         2  ...               1
# 2              1    44             1        97         2  ...               2
# 3              1    48             1        97         2  ...               2
# 4              2    28             1        97         2  ...               2
# ...          ...   ...           ...       ...       ...  ...             ...
# 984283         2    67             1         2         2  ...               2
# 984284         2    81             1         2         1  ...               2
# 984285         2    52             1         2         1  ...               2
# 984286         2    48             1         2         2  ...               2
# 984287         1    67             1         2         1  ...               2
#
#         OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  \
# 0              2              2           1          1            MÃ©xico
# 1              2              2           2          1            MÃ©xico
# 2              2              2           2          1            MÃ©xico
# 3              2              2           2          1            MÃ©xico
# 4              2              2           2          1            MÃ©xico
# ...          ...            ...         ...        ...                ...
# 984283         2              2           2          3            MÃ©xico
# 984284         2              2           1          3            MÃ©xico
# 984285         2              2           2          3            MÃ©xico
# 984286         2              2           2          3            MÃ©xico
# 984287         2              2           2          3            MÃ©xico
#
#         UCI  ENTIDAD_FEDERATIVA  DESCRIPCIÓN_x  DESCRIPCIÓN_y
# 0        97              MÉXICO         HOMBRE    AMBULATORIO
# 1        97              MÉXICO         HOMBRE    AMBULATORIO
# 2        97              MÉXICO         HOMBRE    AMBULATORIO
# 3        97              MÉXICO         HOMBRE    AMBULATORIO
# 4        97              MÉXICO         HOMBRE    AMBULATORIO
# ...     ...                 ...            ...            ...
# 984283    2           ZACATECAS          MUJER  HOSPITALIZADO
# 984284    2           ZACATECAS          MUJER  HOSPITALIZADO
# 984285    2           ZACATECAS          MUJER  HOSPITALIZADO
# 984286    2           ZACATECAS          MUJER  HOSPITALIZADO
# 984287    1           ZACATECAS          MUJER  HOSPITALIZADO
#
# [984288 rows x 24 columns]

# %%
# Ahora tenemos 187.7+ MB de espacio ocupoado en memoria y 24 columnas

covidMERGE.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 984288 entries, 0 to 984287
# Data columns (total 24 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   ENTIDAD_NAC         984288 non-null  int64
#  1   FECHA_INGRESO       984288 non-null  object
#  2   FECHA_SINTOMAS      984288 non-null  object
#  3   FECHA_DEF           984288 non-null  object
#  4   INTUBADO            984288 non-null  int64
#  5   NEUMONIA            984288 non-null  int64
#  6   EDAD                984288 non-null  int64
#  7   NACIONALIDAD        984288 non-null  int64
#  8   EMBARAZO            984288 non-null  int64
#  9   DIABETES            984288 non-null  int64
#  10  EPOC                984288 non-null  int64
#  11  ASMA                984288 non-null  int64
#  12  INMUSUPR            984288 non-null  int64
#  13  HIPERTENSION        984288 non-null  int64
#  14  CARDIOVASCULAR      984288 non-null  int64
#  15  OBESIDAD            984288 non-null  int64
#  16  RENAL_CRONICA       984288 non-null  int64
#  17  TABAQUISMO          984288 non-null  int64
#  18  RESULTADO           984288 non-null  int64
#  19  PAIS_NACIONALIDAD   984288 non-null  object
#  20  UCI                 984288 non-null  int64
#  21  ENTIDAD_FEDERATIVA  984288 non-null  object
#  22  DESCRIPCIÓN_x       984288 non-null  object
#  23  DESCRIPCIÓN_y       984288 non-null  object
# dtypes: int64(17), object(7)
# memory usage: 187.7+ MB

# %%
# renombramos los nombres de columnas 

covidMERGE.rename(columns={"DESCRIPCIÓN_x": "SEXO", "DESCRIPCIÓN_y": "TIPO_PACIENTE"}, inplace = True)
covidMERGE
# Out:
#         ENTIDAD_NAC FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  \
# 0                15    2020-06-12     2020-06-08  9999-99-99        97
# 1                15    2020-06-20     2020-06-20  9999-99-99        97
# 2                15    2020-04-15     2020-04-05  9999-99-99        97
# 3                15    2020-06-15     2020-06-10  9999-99-99        97
# 4                15    2020-04-27     2020-04-27  9999-99-99        97
# ...             ...           ...            ...         ...       ...
# 984283           32    2020-07-27     2020-07-23  9999-99-99         2
# 984284           32    2020-07-30     2020-07-26  9999-99-99         2
# 984285           32    2020-07-28     2020-07-25  9999-99-99         2
# 984286           32    2020-07-06     2020-07-06  9999-99-99         2
# 984287           32    2020-07-30     2020-07-25  9999-99-99         2
#
#         NEUMONIA  EDAD  NACIONALIDAD  EMBARAZO  DIABETES  ...  CARDIOVASCULAR  \
# 0              2    32             1        97         2  ...               2
# 1              2    53             1        97         2  ...               1
# 2              1    44             1        97         2  ...               2
# 3              1    48             1        97         2  ...               2
# 4              2    28             1        97         2  ...               2
# ...          ...   ...           ...       ...       ...  ...             ...
# 984283         2    67             1         2         2  ...               2
# 984284         2    81             1         2         1  ...               2
# 984285         2    52             1         2         1  ...               2
# 984286         2    48             1         2         2  ...               2
# 984287         1    67             1         2         1  ...               2
#
#         OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  \
# 0              2              2           1          1            MÃ©xico
# 1              2              2           2          1            MÃ©xico
# 2              2              2           2          1            MÃ©xico
# 3              2              2           2          1            MÃ©xico
# 4              2              2           2          1            MÃ©xico
# ...          ...            ...         ...        ...                ...
# 984283         2              2           2          3            MÃ©xico
# 984284         2              2           1          3            MÃ©xico
# 984285         2              2           2          3            MÃ©xico
# 984286         2              2           2          3            MÃ©xico
# 984287         2              2           2          3            MÃ©xico
#
#         UCI  ENTIDAD_FEDERATIVA    SEXO  TIPO_PACIENTE
# 0        97              MÉXICO  HOMBRE    AMBULATORIO
# 1        97              MÉXICO  HOMBRE    AMBULATORIO
# 2        97              MÉXICO  HOMBRE    AMBULATORIO
# 3        97              MÉXICO  HOMBRE    AMBULATORIO
# 4        97              MÉXICO  HOMBRE    AMBULATORIO
# ...     ...                 ...     ...            ...
# 984283    2           ZACATECAS   MUJER  HOSPITALIZADO
# 984284    2           ZACATECAS   MUJER  HOSPITALIZADO
# 984285    2           ZACATECAS   MUJER  HOSPITALIZADO
# 984286    2           ZACATECAS   MUJER  HOSPITALIZADO
# 984287    1           ZACATECAS   MUJER  HOSPITALIZADO
#
# [984288 rows x 24 columns]

# %% [markdown]
# ## 5.11 Exportar Dataframe a csv      <a id='id11'> </a>

# %%
# Exportar dataframe a un archivo csv los registros que cumplan los siguientes criterios de
# seleccion de registros


PruebasDgo = covidMERGE[ ( covidMERGE["ENTIDAD_FEDERATIVA"] == "DURANGO") & 
                        (covidMERGE["RESULTADO"] == 1) &
                       (covidMERGE["TIPO_PACIENTE"] == "HOSPITALIZADO" )
                       ]
PruebasDgo
# Out:
#         ENTIDAD_NAC FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  \
# 832115           10    2020-06-26     2020-06-19  9999-99-99         2
# 832116           10    2020-04-17     2020-04-13  2020-04-24         2
# 832117           10    2020-04-14     2020-04-13  9999-99-99         2
# 832118           10    2020-04-06     2020-03-28  2020-04-12         2
# 832119           10    2020-05-09     2020-05-09  9999-99-99         2
# ...             ...           ...            ...         ...       ...
# 932614           10    2020-07-24     2020-07-23  9999-99-99         2
# 932615           10    2020-07-28     2020-07-25  9999-99-99         2
# 932616           10    2020-07-09     2020-07-06  9999-99-99         2
# 932617           10    2020-07-08     2020-07-01  2020-07-22         1
# 932618           10    2020-07-01     2020-07-01  9999-99-99         2
#
#         NEUMONIA  EDAD  NACIONALIDAD  EMBARAZO  DIABETES  ...  CARDIOVASCULAR  \
# 832115         1    41             1        97         2  ...               2
# 832116         1    51             1        97         1  ...               2
# 832117         1    45             1        97         2  ...               2
# 832118         1    43             1        97         2  ...               2
# 832119         1    50             1        97         1  ...               2
# ...          ...   ...           ...       ...       ...  ...             ...
# 932614         1    47             1         2         2  ...               2
# 932615         1    64             1         2         2  ...               2
# 932616         1    84             1         2         1  ...               2
# 932617         1    39             1         2         2  ...               2
# 932618         2    40             1         2         2  ...               2
#
#         OBESIDAD  RENAL_CRONICA  TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  \
# 832115         1              2           2          1            MÃ©xico
# 832116         2              2           2          1            MÃ©xico
# 832117         2              2           2          1            MÃ©xico
# 832118         2              2           2          1            MÃ©xico
# 832119         2              2           1          1            MÃ©xico
# ...          ...            ...         ...        ...                ...
# 932614         1              2           2          1            MÃ©xico
# 932615         2              2           2          1            MÃ©xico
# 932616         1              2           2          1            MÃ©xico
# 932617         1              2           2          1            MÃ©xico
# 932618         2              2           2          1            MÃ©xico
#
#         UCI  ENTIDAD_FEDERATIVA    SEXO  TIPO_PACIENTE
# 832115    2             DURANGO  HOMBRE  HOSPITALIZADO
# 832116    2             DURANGO  HOMBRE  HOSPITALIZADO
# 832117    2             DURANGO  HOMBRE  HOSPITALIZADO
# 832118    2             DURANGO  HOMBRE  HOSPITALIZADO
# 832119    2             DURANGO  HOMBRE  HOSPITALIZADO
# ...     ...                 ...     ...            ...
# 932614    2             DURANGO   MUJER  HOSPITALIZADO
# 932615    2             DURANGO   MUJER  HOSPITALIZADO
# 932616    2             DURANGO   MUJER  HOSPITALIZADO
# 932617    1             DURANGO   MUJER  HOSPITALIZADO
# 932618    2             DURANGO   MUJER  HOSPITALIZADO
#
# [1080 rows x 24 columns]

# %%
# grabamos el dataframe como un archivo de Excel con los datos que filtramos

PruebasDgo.to_csv("Positivos Durango Hospitalizados.csv")

# %%
# Quitar el indice del archivo generado

PruebasDgo.to_csv("Positivos Durango Hospitalizados.csv", index = False)

# %% [markdown]
# ## 5.12  PIVOT  Tables   <a id='id12'> </a>
#
# Devuelve el DataFrame remodelado organizado por los valores de índice/columna especificados.
#
# - Remodele los datos (produzca una tabla "pivote") en función de los valores de las columnas.
# - Utiliza valores únicos de índices/columnas especificados para formar ejes del DataFrame resultante.
# - Esta función no admite la agregación de datos, varios valores darán como resultado un índice múltiple en las columnas.
#
# ![](Pivot.png)

# %%
# Verificamos como estan los datos actualmente

covidMERGE.head()
# Out:
#    ENTIDAD_NAC FECHA_INGRESO FECHA_SINTOMAS   FECHA_DEF  INTUBADO  NEUMONIA  \
# 0           15    2020-06-12     2020-06-08  9999-99-99        97         2
# 1           15    2020-06-20     2020-06-20  9999-99-99        97         2
# 2           15    2020-04-15     2020-04-05  9999-99-99        97         1
# 3           15    2020-06-15     2020-06-10  9999-99-99        97         1
# 4           15    2020-04-27     2020-04-27  9999-99-99        97         2
#
#    EDAD  NACIONALIDAD  EMBARAZO  DIABETES  ...  CARDIOVASCULAR  OBESIDAD  \
# 0    32             1        97         2  ...               2         2
# 1    53             1        97         2  ...               1         2
# 2    44             1        97         2  ...               2         2
# 3    48             1        97         2  ...               2         2
# 4    28             1        97         2  ...               2         2
#
#    RENAL_CRONICA  TABAQUISMO  RESULTADO  PAIS_NACIONALIDAD  UCI  \
# 0              2           1          1            MÃ©xico   97
# 1              2           2          1            MÃ©xico   97
# 2              2           2          1            MÃ©xico   97
# 3              2           2          1            MÃ©xico   97
# 4              2           2          1            MÃ©xico   97
#
#    ENTIDAD_FEDERATIVA    SEXO TIPO_PACIENTE
# 0              MÉXICO  HOMBRE   AMBULATORIO
# 1              MÉXICO  HOMBRE   AMBULATORIO
# 2              MÉXICO  HOMBRE   AMBULATORIO
# 3              MÉXICO  HOMBRE   AMBULATORIO
# 4              MÉXICO  HOMBRE   AMBULATORIO
#
# [5 rows x 24 columns]

# %%
# Realizamos la tabla pivote o tabla dinamica

covidMERGE.pivot_table( values= 'RESULTADO' , index='ENTIDAD_FEDERATIVA', columns='TIPO_PACIENTE', aggfunc=np.size)
# Out:
# TIPO_PACIENTE                    AMBULATORIO  HOSPITALIZADO
# ENTIDAD_FEDERATIVA
# AGUASCALIENTES                          9400           1472
# BAJA CALIFORNIA                        10703           3578
# BAJA CALIFORNIA SUR                     6298            774
# CAMPECHE                                5686           1755
# CHIAPAS                                 8930           3681
# CHIHUAHUA                               8035           3527
# CIUDAD DE MÉXICO                      176473          31241
# COAHUILA DE ZARAGOZA                   31537           3814
# COLIMA                                  2381            739
# DURANGO                                12199           2352
# GUANAJUATO                             43510           7113
# GUERRERO                               19407           5594
# HIDALGO                                 9641           3919
# JALISCO                                30755           8548
# MICHOACÁN DE OCAMPO                    25915           5170
# MORELOS                                 5523           2725
# MÉXICO                                 86330          25906
# NAYARIT                                 5481           1725
# NO ESPECIFICADO                         4274            604
# NUEVO LEÓN                             35503           5811
# OAXACA                                 17275           5923
# PUEBLA                                 33306          10348
# QUERÉTARO                               3603           1925
# QUINTANA ROO                            5340           1108
# SAN LUIS POTOSÍ                        22667           3942
# SINALOA                                20156           7545
# SONORA                                 20895           6108
# TABASCO                                34612           5061
# TAMAULIPAS                             32843           5102
# TLAXCALA                               10209           2795
# VERACRUZ DE IGNACIO DE LA LLAVE        32413          13606
# YUCATÁN                                16373           4113
# ZACATECAS                               6733           2258

# %%
# Realizamos la tabla pivote o tabla dinamica

covidMERGE.pivot_table( values= 'RESULTADO' , index='ENTIDAD_FEDERATIVA', columns='SEXO', aggfunc=np.size)
# Out:
# SEXO                             HOMBRE   MUJER
# ENTIDAD_FEDERATIVA
# AGUASCALIENTES                     4972    5900
# BAJA CALIFORNIA                    6889    7392
# BAJA CALIFORNIA SUR                3272    3800
# CAMPECHE                           4130    3311
# CHIAPAS                            6993    5618
# CHIHUAHUA                          5564    5998
# CIUDAD DE MÉXICO                 102812  104902
# COAHUILA DE ZARAGOZA              16926   18425
# COLIMA                             1495    1625
# DURANGO                            6797    7754
# GUANAJUATO                        24037   26586
# GUERRERO                          12899   12102
# HIDALGO                            7091    6469
# JALISCO                           19048   20255
# MICHOACÁN DE OCAMPO               15270   15815
# MORELOS                            4182    4066
# MÉXICO                            56169   56067
# NAYARIT                            3511    3695
# NO ESPECIFICADO                    2720    2158
# NUEVO LEÓN                        20236   21078
# OAXACA                            12473   10725
# PUEBLA                            22396   21258
# QUERÉTARO                          2749    2779
# QUINTANA ROO                       3281    3167
# SAN LUIS POTOSÍ                   12884   13725
# SINALOA                           13401   14300
# SONORA                            12553   14450
# TABASCO                           19835   19838
# TAMAULIPAS                        19375   18570
# TLAXCALA                           6518    6486
# VERACRUZ DE IGNACIO DE LA LLAVE   25119   20900
# YUCATÁN                           11129    9357
# ZACATECAS                          4465    4526

# %% [markdown]
# ## 5.13 Leer archivo de Excel   <a id='id13'> </a>
#
# Instalar librería  **xlrd**:
#
# - pip install xlrd
# - conda install -c anaconda xlrd
# - Entorno gráfico de Anaconda

# %%
# En este ejmeplo, se abre un archivo de excel en donde los primeros renglones tiene informacion que no es
# relevante importar, se empieza la importacion de registros al dataframe a partir  de la fila 7 donde esta 
# la informacion que se requeire

DiagnosticoIMCO = pd.read_excel('DiagnosticoIMCO.xlsx',
                       sheet_name = 'IMCO',
                      skiprows =range(6),
                      skipfooter=2 )


DiagnosticoIMCO.head()
# Out:
#                 Estado  AportacionesFederales  ParticipacionesFederales  \
# 0       Aguascalientes            10676000000                7158000000
# 1      Baja California            20518000000               19401000000
# 2  Baja California Sur             7173000000                4809000000
# 3             Campeche             8835000000                5628000000
# 4              Chiapas            48873000000               27819000000
#
#    RecaudacionImpuestos        Region
# 0            1232000000  Centro-Norte
# 1            4341000000      Noroeste
# 2            1112000000      Noroeste
# 3            1663000000       Sureste
# 4            1478000000      SurOeste

# %% [markdown]
# ## 5.14 Convertir tipos de datos   <a id='id14'> </a>
#
# - Convertir de Object a Datetime
# - Convertir de Object a Int
# - Convertir de Object a Float

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  object
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](1), int64(8), object(27)
# memory usage: 270.3+ MB

# %%
# En dataframe del COVID las fechas aparecen como tipo object

covid['FECHA_SINTOMAS'] = pd.to_datetime(covid['FECHA_SINTOMAS'], format="%d/%m/%Y")

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 984288 entries, 0 to 984287
# Data columns (total 36 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   FECHA_ACTUALIZACION  984288 non-null  object
#  1   ID_REGISTRO          984288 non-null  object
#  2   ORIGEN               984288 non-null  object
#  3   SECTOR               984288 non-null  int64
#  4   ENTIDAD_UM           984288 non-null  int64
#  5   SEXO                 984288 non-null  object
#  6   ENTIDAD_NAC          984288 non-null  object
#  7   ENTIDAD_RES          984288 non-null  int64
#  8   MUNICIPIO_RES        984288 non-null  int64
#  9   TIPO_PACIENTE        984288 non-null  object
#  10  FECHA_INGRESO        984288 non-null  datetime64[ns]
#  11  FECHA_SINTOMAS       984288 non-null  datetime64[ns]
#  12  FECHA_DEF            984288 non-null  object
#  13  INTUBADO             984288 non-null  object
#  14  NEUMONIA             984288 non-null  object
#  15  EDAD                 984288 non-null  int64
#  16  NACIONALIDAD         984288 non-null  int64
#  17  EMBARAZO             984288 non-null  object
#  18  HABLA_LENGUA_INDIG   984288 non-null  object
#  19  DIABETES             984288 non-null  object
#  20  EPOC                 984288 non-null  object
#  21  ASMA                 984288 non-null  object
#  22  INMUSUPR             984288 non-null  object
#  23  HIPERTENSION         984288 non-null  object
#  24  OTRA_COM             984288 non-null  object
#  25  CARDIOVASCULAR       984288 non-null  object
#  26  OBESIDAD             984288 non-null  object
#  27  RENAL_CRONICA        984288 non-null  object
#  28  TABAQUISMO           984288 non-null  object
#  29  OTRO_CASO            984288 non-null  object
#  30  RESULTADO            984288 non-null  object
#  31  MIGRANTE             984288 non-null  int64
#  32  PAIS_NACIONALIDAD    984288 non-null  object
#  33  PAIS_ORIGEN          984288 non-null  object
#  34  UCI                  984288 non-null  object
#  35  Total                984288 non-null  int64
# dtypes: datetime64[ns](2), int64(8), object(26)
# memory usage: 270.3+ MB

# %% [markdown]
# ## 5.15 Formatting the Display Dataframe  <a id='id15'> </a>
#
# Antes de agregar estilos, es útil mostrar que Styler puede distinguir el valor de visualización del valor real, tanto en valores de datos como en encabezados de índice o columnas.
# - Para controlar el valor de visualización, el texto se imprime en cada celda como una cadena, y podemos usar los métodos .format() y .format_index() para manipular esto de acuerdo con una cadena de especificación de formato o un invocable que toma un valor único y devuelve un String.
# - Es posible definir esto para toda la tabla o índice, o para columnas individuales o niveles MultiIndex.
#
# - Además, la función de formato tiene un argumento de precisión para ayudar específicamente a dar formato a los flotantes, así como separadores decimales y de miles para admitir otras configuraciones regionales,
# - un argumento na_rep para mostrar los datos que faltan
# - un argumento de escape para ayudar a mostrar HTML seguro o LaTeX seguro.
# - El formateador predeterminado está configurado para adoptar la opción **styler.format.precision** de pandas, controlable mediante **pd.option_context('format.precision', 2):**
#
# **Fuente:**
# https://pandas.pydata.org/docs/user_guide/style.html

# %%
DiagnosticoIMCO.head()
# Out:
#             Estado  AportacionesFederales  ParticipacionesFederales  \
# 0   Aguascalientes            10676000000                7158000000
# 1       Guanajuato            30265000000               29097000000
# 2        Queretaro            12321000000               11162000000
# 3  San Luis Potosi            20428000000               13656000000
# 4        Zacatecas            14101000000                7903000000
#
#    RecaudacionImpuestos        Region  Total
# 0            1232000000  Centro-Norte      0
# 1            4373000000  Centro-Norte      0
# 2            2852000000  Centro-Norte      0
# 3            1937000000  Centro-Norte      0
# 4            1192000000  Centro-Norte      0

# %%
DiagnosticoIMCO.head(10).style.format(precision=0, thousands="," , 
                              formatter= {( "AportacionesFederales"): lambda x: "$ {:,.2f}".format(x), 
                                          ( "ParticipacionesFederales"): lambda x: "$ {:,.2f}".format(x),
                                          ( "RecaudacionImpuestos"): lambda x: "$ {:,.1f}".format(x)
                              })
# Out:
# <style type="text/css">
# </style>
# <table id="T_04fa3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04fa3_level0_col0" class="col_heading level0 col0" >Estado</th>
#       <th id="T_04fa3_level0_col1" class="col_heading level0 col1" >AportacionesFederales</th>
#       <th id="T_04fa3_level0_col2" class="col_heading level0 col2" >ParticipacionesFederales</th>
#       <th id="T_04fa3_level0_col3" class="col_heading level0 col3" >RecaudacionImpuestos</th>
#       <th id="T_04fa3_level0_col4" class="col_heading level0 col4" >Region</th>
#       <th id="T_04fa3_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04fa3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04fa3_row0_col0" class="data row0 col0" >Aguascalientes</td>
#       <td id="T_04fa3_row0_col1" class="data row0 col1" >$ 10,676,000,000.00</td>
#       <td id="T_04fa3_row0_col2" class="data row0 col2" >$ 7,158,000,000.00</td>
#       <td id="T_04fa3_row0_col3" class="data row0 col3" >$ 1,232,000,000.0</td>
#       <td id="T_04fa3_row0_col4" class="data row0 col4" >Centro-Norte</td>
#       <td id="T_04fa3_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04fa3_row1_col0" class="data row1 col0" >Guanajuato</td>
#       <td id="T_04fa3_row1_col1" class="data row1 col1" >$ 30,265,000,000.00</td>
#       <td id="T_04fa3_row1_col2" class="data row1 col2" >$ 29,097,000,000.00</td>
#       <td id="T_04fa3_row1_col3" class="data row1 col3" >$ 4,373,000,000.0</td>
#       <td id="T_04fa3_row1_col4" class="data row1 col4" >Centro-Norte</td>
#       <td id="T_04fa3_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_04fa3_row2_col0" class="data row2 col0" >Queretaro</td>
#       <td id="T_04fa3_row2_col1" class="data row2 col1" >$ 12,321,000,000.00</td>
#       <td id="T_04fa3_row2_col2" class="data row2 col2" >$ 11,162,000,000.00</td>
#       <td id="T_04fa3_row2_col3" class="data row2 col3" >$ 2,852,000,000.0</td>
#       <td id="T_04fa3_row2_col4" class="data row2 col4" >Centro-Norte</td>
#       <td id="T_04fa3_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_04fa3_row3_col0" class="data row3 col0" >San Luis Potosi</td>
#       <td id="T_04fa3_row3_col1" class="data row3 col1" >$ 20,428,000,000.00</td>
#       <td id="T_04fa3_row3_col2" class="data row3 col2" >$ 13,656,000,000.00</td>
#       <td id="T_04fa3_row3_col3" class="data row3 col3" >$ 1,937,000,000.0</td>
#       <td id="T_04fa3_row3_col4" class="data row3 col4" >Centro-Norte</td>
#       <td id="T_04fa3_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_04fa3_row4_col0" class="data row4 col0" >Zacatecas</td>
#       <td id="T_04fa3_row4_col1" class="data row4 col1" >$ 14,101,000,000.00</td>
#       <td id="T_04fa3_row4_col2" class="data row4 col2" >$ 7,903,000,000.00</td>
#       <td id="T_04fa3_row4_col3" class="data row4 col3" >$ 1,192,000,000.0</td>
#       <td id="T_04fa3_row4_col4" class="data row4 col4" >Centro-Norte</td>
#       <td id="T_04fa3_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_04fa3_row5_col0" class="data row5 col0" >Ciudad de México</td>
#       <td id="T_04fa3_row5_col1" class="data row5 col1" >$ 16,205,000,000.00</td>
#       <td id="T_04fa3_row5_col2" class="data row5 col2" >$ 68,270,000,000.00</td>
#       <td id="T_04fa3_row5_col3" class="data row5 col3" >$ 58,800,000,000.0</td>
#       <td id="T_04fa3_row5_col4" class="data row5 col4" >Centro-Sur</td>
#       <td id="T_04fa3_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_04fa3_row6_col0" class="data row6 col0" >Estado de México</td>
#       <td id="T_04fa3_row6_col1" class="data row6 col1" >$ 77,925,000,000.00</td>
#       <td id="T_04fa3_row6_col2" class="data row6 col2" >$ 97,088,000,000.00</td>
#       <td id="T_04fa3_row6_col3" class="data row6 col3" >$ 21,451,000,000.0</td>
#       <td id="T_04fa3_row6_col4" class="data row6 col4" >Centro-Sur</td>
#       <td id="T_04fa3_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_04fa3_row7_col0" class="data row7 col0" >Morelos</td>
#       <td id="T_04fa3_row7_col1" class="data row7 col1" >$ 12,967,000,000.00</td>
#       <td id="T_04fa3_row7_col2" class="data row7 col2" >$ 9,668,000,000.00</td>
#       <td id="T_04fa3_row7_col3" class="data row7 col3" >$ 632,000,000.0</td>
#       <td id="T_04fa3_row7_col4" class="data row7 col4" >Centro-Sur</td>
#       <td id="T_04fa3_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_04fa3_row8_col0" class="data row8 col0" >Coahuila</td>
#       <td id="T_04fa3_row8_col1" class="data row8 col1" >$ 17,367,000,000.00</td>
#       <td id="T_04fa3_row8_col2" class="data row8 col2" >$ 15,930,000,000.00</td>
#       <td id="T_04fa3_row8_col3" class="data row8 col3" >$ 2,753,000,000.0</td>
#       <td id="T_04fa3_row8_col4" class="data row8 col4" >Noreste</td>
#       <td id="T_04fa3_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_04fa3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_04fa3_row9_col0" class="data row9 col0" >Nuevo León</td>
#       <td id="T_04fa3_row9_col1" class="data row9 col1" >$ 24,371,000,000.00</td>
#       <td id="T_04fa3_row9_col2" class="data row9 col2" >$ 31,371,000,000.00</td>
#       <td id="T_04fa3_row9_col3" class="data row9 col3" >$ 10,579,000,000.0</td>
#       <td id="T_04fa3_row9_col4" class="data row9 col4" >Noreste</td>
#       <td id="T_04fa3_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
DiagnosticoIMCO.dtypes
# Out:
# Estado                      object
# AportacionesFederales        int64
# ParticipacionesFederales     int64
# RecaudacionImpuestos         int64
# Region                      object
# Total                        int64
# dtype: object

# %%
def make_pretty(styler):
    styler.set_caption("Distribución de Ingresos por estado")
    #styler.background_gradient(axis=None, vmin=1, vmax=2, cmap="YlGnBu")
    return styler

DiagnosticoIMCO.head(10).style.pipe(make_pretty)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d9b0f">
#   <caption>Distribución de Ingresos por estado</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d9b0f_level0_col0" class="col_heading level0 col0" >Estado</th>
#       <th id="T_d9b0f_level0_col1" class="col_heading level0 col1" >AportacionesFederales</th>
#       <th id="T_d9b0f_level0_col2" class="col_heading level0 col2" >ParticipacionesFederales</th>
#       <th id="T_d9b0f_level0_col3" class="col_heading level0 col3" >RecaudacionImpuestos</th>
#       <th id="T_d9b0f_level0_col4" class="col_heading level0 col4" >Region</th>
#       <th id="T_d9b0f_level0_col5" class="col_heading level0 col5" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9b0f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9b0f_row0_col0" class="data row0 col0" >Aguascalientes</td>
#       <td id="T_d9b0f_row0_col1" class="data row0 col1" >10676000000</td>
#       <td id="T_d9b0f_row0_col2" class="data row0 col2" >7158000000</td>
#       <td id="T_d9b0f_row0_col3" class="data row0 col3" >1232000000</td>
#       <td id="T_d9b0f_row0_col4" class="data row0 col4" >Centro-Norte</td>
#       <td id="T_d9b0f_row0_col5" class="data row0 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9b0f_row1_col0" class="data row1 col0" >Guanajuato</td>
#       <td id="T_d9b0f_row1_col1" class="data row1 col1" >30265000000</td>
#       <td id="T_d9b0f_row1_col2" class="data row1 col2" >29097000000</td>
#       <td id="T_d9b0f_row1_col3" class="data row1 col3" >4373000000</td>
#       <td id="T_d9b0f_row1_col4" class="data row1 col4" >Centro-Norte</td>
#       <td id="T_d9b0f_row1_col5" class="data row1 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9b0f_row2_col0" class="data row2 col0" >Queretaro</td>
#       <td id="T_d9b0f_row2_col1" class="data row2 col1" >12321000000</td>
#       <td id="T_d9b0f_row2_col2" class="data row2 col2" >11162000000</td>
#       <td id="T_d9b0f_row2_col3" class="data row2 col3" >2852000000</td>
#       <td id="T_d9b0f_row2_col4" class="data row2 col4" >Centro-Norte</td>
#       <td id="T_d9b0f_row2_col5" class="data row2 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9b0f_row3_col0" class="data row3 col0" >San Luis Potosi</td>
#       <td id="T_d9b0f_row3_col1" class="data row3 col1" >20428000000</td>
#       <td id="T_d9b0f_row3_col2" class="data row3 col2" >13656000000</td>
#       <td id="T_d9b0f_row3_col3" class="data row3 col3" >1937000000</td>
#       <td id="T_d9b0f_row3_col4" class="data row3 col4" >Centro-Norte</td>
#       <td id="T_d9b0f_row3_col5" class="data row3 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9b0f_row4_col0" class="data row4 col0" >Zacatecas</td>
#       <td id="T_d9b0f_row4_col1" class="data row4 col1" >14101000000</td>
#       <td id="T_d9b0f_row4_col2" class="data row4 col2" >7903000000</td>
#       <td id="T_d9b0f_row4_col3" class="data row4 col3" >1192000000</td>
#       <td id="T_d9b0f_row4_col4" class="data row4 col4" >Centro-Norte</td>
#       <td id="T_d9b0f_row4_col5" class="data row4 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9b0f_row5_col0" class="data row5 col0" >Ciudad de México</td>
#       <td id="T_d9b0f_row5_col1" class="data row5 col1" >16205000000</td>
#       <td id="T_d9b0f_row5_col2" class="data row5 col2" >68270000000</td>
#       <td id="T_d9b0f_row5_col3" class="data row5 col3" >58800000000</td>
#       <td id="T_d9b0f_row5_col4" class="data row5 col4" >Centro-Sur</td>
#       <td id="T_d9b0f_row5_col5" class="data row5 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9b0f_row6_col0" class="data row6 col0" >Estado de México</td>
#       <td id="T_d9b0f_row6_col1" class="data row6 col1" >77925000000</td>
#       <td id="T_d9b0f_row6_col2" class="data row6 col2" >97088000000</td>
#       <td id="T_d9b0f_row6_col3" class="data row6 col3" >21451000000</td>
#       <td id="T_d9b0f_row6_col4" class="data row6 col4" >Centro-Sur</td>
#       <td id="T_d9b0f_row6_col5" class="data row6 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9b0f_row7_col0" class="data row7 col0" >Morelos</td>
#       <td id="T_d9b0f_row7_col1" class="data row7 col1" >12967000000</td>
#       <td id="T_d9b0f_row7_col2" class="data row7 col2" >9668000000</td>
#       <td id="T_d9b0f_row7_col3" class="data row7 col3" >632000000</td>
#       <td id="T_d9b0f_row7_col4" class="data row7 col4" >Centro-Sur</td>
#       <td id="T_d9b0f_row7_col5" class="data row7 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9b0f_row8_col0" class="data row8 col0" >Coahuila</td>
#       <td id="T_d9b0f_row8_col1" class="data row8 col1" >17367000000</td>
#       <td id="T_d9b0f_row8_col2" class="data row8 col2" >15930000000</td>
#       <td id="T_d9b0f_row8_col3" class="data row8 col3" >2753000000</td>
#       <td id="T_d9b0f_row8_col4" class="data row8 col4" >Noreste</td>
#       <td id="T_d9b0f_row8_col5" class="data row8 col5" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d9b0f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9b0f_row9_col0" class="data row9 col0" >Nuevo León</td>
#       <td id="T_d9b0f_row9_col1" class="data row9 col1" >24371000000</td>
#       <td id="T_d9b0f_row9_col2" class="data row9 col2" >31371000000</td>
#       <td id="T_d9b0f_row9_col3" class="data row9 col3" >10579000000</td>
#       <td id="T_d9b0f_row9_col4" class="data row9 col4" >Noreste</td>
#       <td id="T_d9b0f_row9_col5" class="data row9 col5" >0</td>
#     </tr>
#   </tbody>
# </table>
